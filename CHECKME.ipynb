# %%
import os
import time

import numpy as np
import pandas as pd

from catboost import CatBoostRegressor, Pool
from sklearn.metrics import mean_squared_error

from app.Encoder import Encoder

# %%
data = pd.read_csv('./X_train.csv')
aircraft_grp_encoder = Encoder(data['aircraft_grp'].unique())

# %%
# Generate available metrics for each pair ('engine_type', 'flight_phase') 

def get_engine_targets():
    data = pd.read_csv('./X_train.csv')
    y = pd.read_csv('./y_train.csv')
    y = y.drop(columns=['VSVNOM'])
    y['engine_type'] = data[data['engine_id'] == y['engine_id']]['engine_type']
    targets = {}
    for engine, df in y.groupby(['engine_type', 'flight_phase']):
        df = df.drop(columns=['flight_datetime', 'engine_id', 'flight_phase', 'engine_type'])
        size = df.shape[0]
        key = ' '.join([str(x) for x in engine]).replace('/', '_')
        for column in df.columns:
            # Fillter out columns (targets) with a lot of NaNs or with identical values
            if df[column].isna().sum() / size < 0.3 and (df[column].max() - df[column].min()) > 0.0001:
                engine_targets = targets.get(key, [])
                engine_targets.append(column)
                targets[key] = engine_targets

    return targets

# %%
def generate_dataset(key: str, metric:str, x: pd.DataFrame, y: pd.DataFrame,
                     empty:list = None):
    engine_type, flight_phase = key.split(' ')
    x['target'] = y[y['engine_id'] == x['engine_id']][metric]
    x = x[x['engine_type'] == engine_type] 
    x = x[x['flight_phase'] == flight_phase]
    # Remove columns (features) with a lot of NaNs
    if(empty is None):
        empty = []
        size = x.shape[0]
        for column in x.drop(columns=['target', 'flight_phase']).columns:
            if (x[column].isna().sum() / size) > 0.7:
                empty.append(column)
    x = x.drop(columns=empty)
    x = x[x['target'].notna()]
    x['aircraft_grp'] = x['aircraft_grp'].apply(aircraft_grp_encoder.encode_single)
    x = x.fillna(-100)
    features = x.drop(columns=['target', 'engine_id', 'aircraft_id', 'flight_datetime',
                               'engine_family', 'engine_type', 'manufacturer',
                               'ac_manufacturer', 'aircraft_type', 'aircraft_family',
                               'flight_phase'])
    return features, x['target'], empty

# %%
def generate_val_part(key: str, metric:str, x: pd.DataFrame,
                      aircraft_grp_encoder: Encoder, empty:list = None):
    engine_type, flight_phase = key.split(' ')
    x = x[x['engine_type'] == engine_type] 
    x = x[x['flight_phase'] == flight_phase]
    if(empty is None):
        empty = []
        size = x.shape[0]
        for column in x.drop(columns=['engine_type', 'flight_phase']).columns:
            if (x[column].isna().sum() / size) > 0.7:
                empty.append(column)
    x = x.drop(columns=empty)
    x['aircraft_grp'] = x['aircraft_grp'].apply(aircraft_grp_encoder.encode_single)
    x = x.fillna(-100)
    features = x.drop(columns=['engine_id', 'aircraft_id', 'flight_datetime',
                               'engine_family', 'engine_type', 'manufacturer',
                               'ac_manufacturer', 'aircraft_type', 'aircraft_family',
                               'flight_phase'])
    return x[['engine_id', 'flight_datetime', 'flight_phase']], features, empty

# %%
def generate_full_dataset(key: str, metric:str, x: pd.DataFrame, y: pd.DataFrame, 
                          x_te: pd.DataFrame, y_te: pd.DataFrame):
    x_train, y_train, empty = generate_dataset(key, metric, x, y)
    x_test, y_test, _ = generate_dataset(key, metric, x_te, y_te, empty)
    return x_train, y_train, x_test, y_test, empty

# %%
def train_model(key: str, metric:str, x: pd.DataFrame, y: pd.DataFrame,
                x_te: pd.DataFrame, y_te: pd.DataFrame):
    t_start = time.time()
    x_train, y_train, x_test, y_test, empty = generate_full_dataset(
        key,
        metric,
        x,
        y,
        x_te,
        y_te
    )
    train_pool = Pool(x_train, y_train)
    val_pool = Pool(x_test, y_test)
    test_pool = Pool(x_test)
    t_data = time.time() - t_start
    t_train = time.time()
    model = CatBoostRegressor(iterations=800, loss_function='RMSE',
                              logging_level='Silent', use_best_model=True,
                              early_stopping_rounds=150, max_depth=4)
    model.fit(train_pool, eval_set=val_pool)
    t_train = time.time() - t_train
    rmse = mean_squared_error(y_test, model.predict(test_pool), squared=False)
    print(f'Key: {key}, metric: {metric} \n\t rmse: {rmse}, percentage: {rmse / max(y_train.max() - y_train.min(), 0.0001) * 100}\n\tData time: {t_data}, train_time: {t_train}, overall_time: {time.time() - t_start}')
    return model

# %%
def train_all_models(root_path: str = "models"):
    if not os.path.exists(root_path):
        os.mkdir(root_path)
    index = len(list(os.listdir(root_path))) + 1
    os.mkdir(os.path.join(root_path, f'exp{index}'))
    targets = get_engine_targets()
    x = pd.read_csv('X_train.csv')
    # Replace / to avoid system conflicts with paths
    x['engine_type'] = x['engine_type'].map(lambda x: x.replace('/', '_'))
    x = x.astype({'n1_modifier': 'int32'})
    y = pd.read_csv('y_train.csv')
    x_te = pd.read_csv('X_test.csv')
    x_te['engine_type'] = x_te['engine_type'].map(lambda x: x.replace('/', '_'))
    x_te = x_te.astype({'n1_modifier': 'int32'})
    y_te = pd.read_csv('y_test.csv')
    for key, metrics in targets.items():
        os.mkdir(os.path.join(root_path, f'exp{index}', key))
        for metric in metrics:
            model = train_model(key, metric, x, y, x_te, y_te)
            model.save_model(
                os.path.join(root_path, f'exp{index}', key, f'{metric}.cbm')
            )

# %%
def evaluate_all_models(exp_index: int, root_path: str = "models"):
    targets = get_engine_targets()
    x = pd.read_csv('X_train.csv')
    x['engine_type'] = x['engine_type'].map(lambda x: x.replace('/', '_'))
    x = x.astype({'n1_modifier': 'int32'})
    y = pd.read_csv('y_train.csv')
    x_te = pd.read_csv('X_test.csv')
    x_te['engine_type'] = x_te['engine_type'].map(lambda x: x.replace('/', '_'))
    x_te = x_te.astype({'n1_modifier': 'int32'})
    y_te = pd.read_csv('y_test.csv')
    scores = {}
    for key, metrics in targets.items():
        for metric in metrics:
            model = CatBoostRegressor().load_model(
                os.path.join(root_path, f'exp{exp_index}', key, f'{metric}.cbm')
            )
            
            _, y_train, x_test, y_test, _ = generate_full_dataset(
                key,
                metric,
                x,
                y,
                x_te,
                y_te
            )
            test_pool = Pool(x_test)
            rmse = mean_squared_error(y_test, model.predict(test_pool), squared=False)
            engine_scores = scores.get(key, {})
            engine_scores[metric] = {
                'rmse': rmse,
                'percent': rmse / (max(y_train.max() - y_train.min(), 0.01)) * 100
            }
            scores[key] = engine_scores
    return scores

# %%
def get_overall_score(exp_index: int):
    scores = evaluate_all_models(exp_index)
    overall_scores = {}
    for key, metrics in scores.items():
        for metric, val in metrics.items():
            overall_score = overall_scores.get(metric, {'score': 0, 'n': 0})
            overall_score['score'] = overall_score['score'] + val['rmse']
            overall_score['n'] = overall_score['n'] + 1
            overall_scores[metric] = overall_score
    result = {}
    y = pd.read_csv('y_train.csv')
    for metric, val in overall_scores.items():
        result[metric] = [
            val['score'] / val['n'],
            (val['score'] / val['n']) / max(
                y[metric].max() - y[metric].min(), 0.0001
            ) * 100
        ]
        result

    result_scores = pd.DataFrame.from_dict(result, orient='index',
                                           columns=['rmse', 'percent error'])
    result_scores['rmse'] = result_scores['rmse'].apply(lambda x: '%.3f' % x)
    result_scores['percent error'] = \
        result_scores['percent error'].apply(lambda x: f'{round(x, 2)}%')
    result_scores = result_scores.sort_index()
    return result_scores

# %%
def predict(filepath: str, models_dir: str) -> pd.DataFrame:
    x_val = pd.read_csv(filepath)
    x_val['engine_type'] = x_val['engine_type'].map(lambda x: x.replace('/', '_'))
    x = pd.read_csv('X_train.csv')
    x['engine_type'] = x['engine_type'].map(lambda x: x.replace('/', '_'))
    x = x.astype({'n1_modifier': 'int32'})
    aircraft_grp_encoder = Encoder(x['aircraft_grp'].unique())
    targets = get_engine_targets()
    result = None
    for key, metrics in targets.items():
        df = None
        for metric in metrics:
            _, _, empty = generate_val_part(key, metric, x, aircraft_grp_encoder)
            ids, x_val_part, _ = generate_val_part(
                key, metric, x_val, aircraft_grp_encoder, empty
            )
            model = CatBoostRegressor().load_model(
                os.path.join(models_dir, key, f'{metric}.cbm')
            )
            prediction = model.predict(x_val_part)
            ids[metric] = prediction
            if df is None:
                df = ids
            else:
                df = pd.merge(
                    df,
                    ids, 
                    on=['engine_id', 'flight_datetime', 'flight_phase'],
                    how='outer'
                )
        if result is None:
            result = df
        else:
            result = pd.concat((result, df))

    # VSVNOM always contains either NaN or 0.0, it is not predicted
    result["VSVNOM"] = 0.
    result = result.fillna(result.mean())
    return result

# %% [markdown]
# ### Train models

# %%
train_all_models()
# Out:
# Key: CF34-8E5 CRUISE, metric: BRAT
# 	 rmse: 0.004878300745304771, percentage: 0.4878300745304771
# 	Data time: 0.19699525833129883, train_time: 4.618396282196045, overall_time: 4.822413206100464
# Key: CF34-8E5 CRUISE, metric: DEGT
# 	 rmse: 2.22838319449058, percentage: 1.9661054040343418
# 	Data time: 0.1549839973449707, train_time: 3.286564588546753, overall_time: 3.4445247650146484
# Key: CF34-8E5 CRUISE, metric: EGTC
# 	 rmse: 1.6164443630145424, percentage: 0.4750323744352746
# 	Data time: 0.13700318336486816, train_time: 2.377014398574829, overall_time: 2.51900315284729
# Key: CF34-8E5 CRUISE, metric: GPCN25
# 	 rmse: 0.0844384539467183, percentage: 3.1264342167431054
# 	Data time: 0.13900136947631836, train_time: 2.4801418781280518, overall_time: 2.6231424808502197
# Key: CF34-8E5 CRUISE, metric: GWFM
# 	 rmse: 0.807489249894825, percentage: 4.381719097659683
# 	Data time: 0.13901877403259277, train_time: 2.9363949298858643, overall_time: 3.079414129257202
# Key: CF34-8E5 CRUISE, metric: PCN12
# 	 rmse: 0.08802846723937047, percentage: 0.33942410113162946
# 	Data time: 0.14600658416748047, train_time: 2.4096338748931885, overall_time: 2.5596420764923096
# Key: CF34-8E5 CRUISE, metric: PCN12I
# 	 rmse: 0.07671202919629028, percentage: 0.29543169883290876
# 	Data time: 0.12900066375732422, train_time: 2.5147178173065186, overall_time: 2.64871883392334
# Key: CF34-8E5 CRUISE, metric: PCN1K
# 	 rmse: 0.09792331948809181, percentage: 0.37384342099149664
# 	Data time: 0.16552138328552246, train_time: 2.406362771987915, overall_time: 2.57588267326355
# Key: CF34-8E5 CRUISE, metric: PCN2C
# 	 rmse: 0.08077952045997747, percentage: 0.6667040252579277
# 	Data time: 0.139143705368042, train_time: 2.4120967388153076, overall_time: 2.555224895477295
# Key: CF34-8E5 CRUISE, metric: WBI
# 	 rmse: 0.004878300877470026, percentage: 0.4878300877470026
# 	Data time: 0.12799930572509766, train_time: 2.341017723083496, overall_time: 2.474015951156616
# Key: CF34-8E5 CRUISE, metric: WFMP
# 	 rmse: 12.034596797069629, percentage: 1.064740797935403
# 	Data time: 0.12900781631469727, train_time: 2.67848539352417, overall_time: 2.8104920387268066
# Key: CF34-8E5 CRUISE, metric: ZPCN25_D
# 	 rmse: 0.07823169147646312, percentage: 4.957183802058424
# 	Data time: 0.13701105117797852, train_time: 2.4918973445892334, overall_time: 2.632908821105957
# Key: CF34-8E5 CRUISE, metric: ZT49_D
# 	 rmse: 5.31535070209486, percentage: 8.87741244608745
# 	Data time: 0.1329784393310547, train_time: 2.7868130207061768, overall_time: 2.9237937927246094
# Key: CF34-8E5 CRUISE, metric: ZTLA_D
# 	 rmse: 0.060449008928390016, percentage: 0.9145991571935441
# 	Data time: 0.1410844326019287, train_time: 1.400914192199707, overall_time: 1.5439984798431396
# Key: CF34-8E5 CRUISE, metric: ZWF36_D
# 	 rmse: 13.848984145708549, percentage: 7.633025421090557
# 	Data time: 0.14208555221557617, train_time: 2.425516366958618, overall_time: 2.571608066558838
# Key: CF34-8E5 TAKEOFF, metric: BRAT
# 	 rmse: 0.004562446312094509, percentage: 0.45624463120945086
# 	Data time: 0.13009214401245117, train_time: 6.559361934661865, overall_time: 6.693453788757324
# Key: CF34-8E5 TAKEOFF, metric: EGTHDM
# 	 rmse: 1.5760457925926048, percentage: 1.2194844707792896
# 	Data time: 0.14798665046691895, train_time: 3.009791374206543, overall_time: 3.161776542663574
# Key: CF34-8E5 TAKEOFF, metric: EGTHDM_D
# 	 rmse: 5.702193929440089, percentage: 8.343174461254597
# 	Data time: 0.1530134677886963, train_time: 2.849778175354004, overall_time: 3.007791042327881
# Key: CF34-8E5 TAKEOFF, metric: PCN12
# 	 rmse: 0.06177210083755047, percentage: 0.3350462153743681
# 	Data time: 0.15600299835205078, train_time: 2.668365955352783, overall_time: 2.829371452331543
# Key: CF34-8E5 TAKEOFF, metric: PCN1K
# 	 rmse: 0.05641224228502276, percentage: 0.538828652794726
# 	Data time: 0.14679741859436035, train_time: 2.466000556945801, overall_time: 2.6167972087860107
# Key: CF34-8E5 TAKEOFF, metric: SLOATL
# 	 rmse: 0.453021446465461, percentage: 1.2276823875899647
# 	Data time: 0.13201904296875, train_time: 2.584296703338623, overall_time: 2.7203176021575928
# Key: CF34-8E5 TAKEOFF, metric: SLOATL_D
# 	 rmse: 1.6217405967097642, percentage: 8.152698708248987
# 	Data time: 0.14701628684997559, train_time: 2.630985736846924, overall_time: 2.7829911708831787
# Key: CF34-8E5 TAKEOFF, metric: ZPCN25_D
# 	 rmse: 0.06891486679742158, percentage: 9.188648906322877
# 	Data time: 0.14399933815002441, train_time: 2.5196945667266846, overall_time: 2.667696237564087
# Key: CF34-8E5 TAKEOFF, metric: ZT49_D
# 	 rmse: 5.355521907537683, percentage: 7.890271686980012
# 	Data time: 0.13397598266601562, train_time: 2.746019124984741, overall_time: 2.885998249053955
# Key: CF34-8E5 TAKEOFF, metric: ZWF36_D
# 	 rmse: 25.871648699511315, percentage: 7.059112878447834
# 	Data time: 0.17067313194274902, train_time: 2.3481826782226562, overall_time: 2.5238375663757324
# Key: CFM56-5B3 CRUISE, metric: BRAT
# 	 rmse: 0.01913429164663804, percentage: 1.0808020309232687
# 	Data time: 0.08896732330322266, train_time: 2.301978826522827, overall_time: 2.3949472904205322
# Key: CFM56-5B3 CRUISE, metric: DEGT
# 	 rmse: 2.32067717668759, percentage: 3.7773163052809013
# 	Data time: 0.17233872413635254, train_time: 1.6622648239135742, overall_time: 1.8386049270629883
# Key: CFM56-5B3 CRUISE, metric: DELVSV
# 	 rmse: 0.01829790641463214, percentage: 0.13554005129083507
# 	Data time: 0.0950014591217041, train_time: 1.400000810623169, overall_time: 1.4970006942749023
# Key: CFM56-5B3 CRUISE, metric: DPOIL
# 	 rmse: 0.07443644320456776, percentage: 0.4904619257546942
# 	Data time: 0.09097957611083984, train_time: 1.5340254306793213, overall_time: 1.6290032863616943
# Key: CFM56-5B3 CRUISE, metric: EGTC
# 	 rmse: 1.0770252112905319, percentage: 0.5555189316861412
# 	Data time: 0.11296820640563965, train_time: 1.570420503616333, overall_time: 1.686384916305542
# Key: CFM56-5B3 CRUISE, metric: EGTHDM
# 	 rmse: 3.519817965491102, percentage: 4.196907223887961
# 	Data time: 0.11801695823669434, train_time: 1.6155304908752441, overall_time: 1.737523078918457
# Key: CFM56-5B3 CRUISE, metric: GEGTMC
# 	 rmse: 2.3172708761121728, percentage: 3.771771697560164
# 	Data time: 0.13138437271118164, train_time: 1.8549752235412598, overall_time: 1.9903414249420166
# Key: CFM56-5B3 CRUISE, metric: GN2MC
# 	 rmse: 0.06473357708510528, percentage: 3.7900330504824136
# 	Data time: 0.11797380447387695, train_time: 1.6065804958343506, overall_time: 1.727552890777588
# Key: CFM56-5B3 CRUISE, metric: GPCN25
# 	 rmse: 0.06473356706740216, percentage: 3.7900236057568573
# 	Data time: 0.10697698593139648, train_time: 1.6580207347869873, overall_time: 1.7669968605041504
# Key: CFM56-5B3 CRUISE, metric: GWFM
# 	 rmse: 0.36087857917811683, percentage: 2.9249463390887067
# 	Data time: 0.1130220890045166, train_time: 1.6304116249084473, overall_time: 1.7454164028167725
# Key: CFM56-5B3 CRUISE, metric: PCN12
# 	 rmse: 0.06546299423855446, percentage: 0.14911843246619488
# 	Data time: 0.09700202941894531, train_time: 1.490368127822876, overall_time: 1.5903675556182861
# Key: CFM56-5B3 CRUISE, metric: PCN12I
# 	 rmse: 0.06546299423855446, percentage: 0.14911843246619488
# 	Data time: 0.09309625625610352, train_time: 1.3518962860107422, overall_time: 1.4479916095733643
# Key: CFM56-5B3 CRUISE, metric: PCN1K
# 	 rmse: 0.14989898376114918, percentage: 0.8332549245388562
# 	Data time: 0.10698461532592773, train_time: 1.5223402976989746, overall_time: 1.63232421875
# Key: CFM56-5B3 CRUISE, metric: PCN2C
# 	 rmse: 0.052245883892756466, percentage: 0.5885443472660935
# 	Data time: 0.09799981117248535, train_time: 1.5384221076965332, overall_time: 1.6384220123291016
# Key: CFM56-5B3 CRUISE, metric: SLOATL
# 	 rmse: 1.0442742344234068, percentage: 4.239253585965659
# 	Data time: 0.09009289741516113, train_time: 1.2859082221984863, overall_time: 1.3790013790130615
# Key: CFM56-5B3 CRUISE, metric: WBE
# 	 rmse: 0.44635868679014057, percentage: 0.3846217498037774
# 	Data time: 0.0800027847290039, train_time: 1.470613956451416, overall_time: 1.5526378154754639
# Key: CFM56-5B3 CRUISE, metric: WBI
# 	 rmse: 0.01855124281310235, percentage: 1.047867836483059
# 	Data time: 0.10329604148864746, train_time: 1.4740633964538574, overall_time: 1.5793609619140625
# Key: CFM56-5B3 CRUISE, metric: WFMP
# 	 rmse: 22.10374001454646, percentage: 1.2191710041887853
# 	Data time: 0.08900117874145508, train_time: 1.3541240692138672, overall_time: 1.4461252689361572
# Key: CFM56-5B3 CRUISE, metric: ZPCN25_D
# 	 rmse: 0.035659502561019775, percentage: 5.0941258100201265
# 	Data time: 0.0880129337310791, train_time: 1.3729846477508545, overall_time: 1.462998390197754
# Key: CFM56-5B3 CRUISE, metric: ZT49_D
# 	 rmse: 1.5465955792500437, percentage: 5.172556244636522
# 	Data time: 0.08102226257324219, train_time: 1.4126782417297363, overall_time: 1.4957082271575928
# Key: CFM56-5B3 CRUISE, metric: ZTNAC_D
# 	 rmse: 1.8430773557642994, percentage: 2.5247635010469853
# 	Data time: 0.08528614044189453, train_time: 1.461944818496704, overall_time: 1.5502314567565918
# Key: CFM56-5B3 CRUISE, metric: ZWF36_D
# 	 rmse: 4.912704846011486, percentage: 2.475961845218891
# 	Data time: 0.10901999473571777, train_time: 1.3859798908233643, overall_time: 1.4979991912841797
# Key: CFM56-5B3 TAKEOFF, metric: BRAT
# 	 rmse: 0.027000776355983122, percentage: 2.5933534891279058
# 	Data time: 0.06899905204772949, train_time: 0.8726909160614014, overall_time: 0.9436898231506348
# Key: CFM56-5B3 TAKEOFF, metric: DELFN
# 	 rmse: 0.6263965365992472, percentage: 2.0598151820158326
# 	Data time: 0.11984086036682129, train_time: 1.6921796798706055, overall_time: 1.8210206031799316
# Key: CFM56-5B3 TAKEOFF, metric: DELN1
# 	 rmse: 0.31684163364393153, percentage: 2.411351504790473
# 	Data time: 0.15504074096679688, train_time: 0.8940010070800781, overall_time: 1.0510430335998535
# Key: CFM56-5B3 TAKEOFF, metric: EGTHDM
# 	 rmse: 6.483247869072053, percentage: 4.941741977765978
# 	Data time: 0.07799744606018066, train_time: 0.7870016098022461, overall_time: 0.8659987449645996
# Key: CFM56-5B3 TAKEOFF, metric: EGTHDM_D
# 	 rmse: 3.641458965856161, percentage: 9.688733847269656
# 	Data time: 0.0670022964477539, train_time: 0.43599677085876465, overall_time: 0.5059983730316162
# Key: CFM56-5B3 TAKEOFF, metric: PCN12
# 	 rmse: 0.24640562558340215, percentage: 1.4676843394663626
# 	Data time: 0.0950009822845459, train_time: 0.7986490726470947, overall_time: 0.8956491947174072
# Key: CFM56-5B3 TAKEOFF, metric: PCN12I
# 	 rmse: 0.22977301671838637, percentage: 1.3516059886470133
# 	Data time: 0.09813094139099121, train_time: 0.8688399791717529, overall_time: 0.9689755439758301
# Key: CFM56-5B3 TAKEOFF, metric: PCN1AR
# 	 rmse: 0.2693389777878322, percentage: 1.927653652756734
# 	Data time: 0.06898379325866699, train_time: 0.7667908668518066, overall_time: 0.8377628326416016
# Key: CFM56-5B3 TAKEOFF, metric: PCN1BR
# 	 rmse: 4.415937131370367, percentage: 4.426580419036219
# 	Data time: 0.07797789573669434, train_time: 0.7980170249938965, overall_time: 0.877976655960083
# Key: CFM56-5B3 TAKEOFF, metric: PCN1K
# 	 rmse: 0.331109949397096, percentage: 2.351629037959685
# 	Data time: 0.07497072219848633, train_time: 0.7190003395080566, overall_time: 0.7959892749786377
# Key: CFM56-5B3 TAKEOFF, metric: SLOATL
# 	 rmse: 1.852110914590507, percentage: 4.907901872311283
# 	Data time: 0.07205557823181152, train_time: 0.7609446048736572, overall_time: 0.8349997997283936
# Key: CFM56-5B3 TAKEOFF, metric: SLOATL_D
# 	 rmse: 1.0555761384020135, percentage: 9.51634998129925
# 	Data time: 0.07400083541870117, train_time: 0.3640017509460449, overall_time: 0.4400014877319336
# Key: CFM56-5B3 TAKEOFF, metric: ZPCN25_D
# 	 rmse: 0.08036679796143739, percentage: 11.480896052288019
# 	Data time: 0.08663296699523926, train_time: 0.5156722068786621, overall_time: 0.604299783706665
# Key: CFM56-5B3 TAKEOFF, metric: ZT49_D
# 	 rmse: 3.441807338837857, percentage: 9.36546214649757
# 	Data time: 0.06199812889099121, train_time: 0.3860013484954834, overall_time: 0.4500000476837158
# Key: CFM56-5B4 CRUISE, metric: BRAT
# 	 rmse: 0.008164416315962182, percentage: 0.44612078393709287
# 	Data time: 0.149000883102417, train_time: 3.0489652156829834, overall_time: 3.2019665241241455
# Key: CFM56-5B4 CRUISE, metric: DEGT
# 	 rmse: 1.964175063418169, percentage: 0.9292878845977699
# 	Data time: 0.1170964241027832, train_time: 2.0993635654449463, overall_time: 2.220463752746582
# Key: CFM56-5B4 CRUISE, metric: DELVSV
# 	 rmse: 0.028042575394950454, percentage: 0.1540800778148892
# 	Data time: 0.12700152397155762, train_time: 1.9269976615905762, overall_time: 2.0590195655822754
# Key: CFM56-5B4 CRUISE, metric: DPOIL
# 	 rmse: 0.05475626710280112, percentage: 0.31136130102353204
# 	Data time: 0.11098837852478027, train_time: 2.093885660171509, overall_time: 2.207855701446533
# Key: CFM56-5B4 CRUISE, metric: EGTC
# 	 rmse: 1.0295675151866643, percentage: 0.46910389343669257
# 	Data time: 0.12005496025085449, train_time: 2.027153491973877, overall_time: 2.1521942615509033
# Key: CFM56-5B4 CRUISE, metric: EGTHDM
# 	 rmse: 3.762357974599464, percentage: 1.347825201458401
# 	Data time: 0.12600064277648926, train_time: 1.9645347595214844, overall_time: 2.094515323638916
# Key: CFM56-5B4 CRUISE, metric: GEGTMC
# 	 rmse: 1.973186318830744, percentage: 0.9335501284807245
# 	Data time: 0.11871933937072754, train_time: 2.104029417037964, overall_time: 2.2257490158081055
# Key: CFM56-5B4 CRUISE, metric: GN2MC
# 	 rmse: 0.08055806241989816, percentage: 0.9513907293187431
# 	Data time: 0.13400721549987793, train_time: 1.9879984855651855, overall_time: 2.126999616622925
# Key: CFM56-5B4 CRUISE, metric: GPCN25
# 	 rmse: 0.08055808727981706, percentage: 0.9513917161716593
# 	Data time: 0.11799955368041992, train_time: 2.084102153778076, overall_time: 2.2060821056365967
# Key: CFM56-5B4 CRUISE, metric: GWFM
# 	 rmse: 0.40557964065368624, percentage: 0.5713384351218912
# 	Data time: 0.1170969009399414, train_time: 2.0068485736846924, overall_time: 2.1279706954956055
# Key: CFM56-5B4 CRUISE, metric: PCN12
# 	 rmse: 0.08029869988789515, percentage: 0.203803799063041
# 	Data time: 0.11298370361328125, train_time: 2.058886766433716, overall_time: 2.175870656967163
# Key: CFM56-5B4 CRUISE, metric: PCN12I
# 	 rmse: 0.08029869988789515, percentage: 0.203803799063041
# 	Data time: 0.1230001449584961, train_time: 2.0120744705200195, overall_time: 2.1390328407287598
# Key: CFM56-5B4 CRUISE, metric: PCN1K
# 	 rmse: 0.12318580207514937, percentage: 0.32928488573597325
# 	Data time: 0.12006878852844238, train_time: 2.6954598426818848, overall_time: 2.818528890609741
# Key: CFM56-5B4 CRUISE, metric: PCN2C
# 	 rmse: 0.05002531581559922, percentage: 0.48551782330839455
# 	Data time: 0.12197470664978027, train_time: 2.2179911136627197, overall_time: 2.3469643592834473
# Key: CFM56-5B4 CRUISE, metric: SLOATL
# 	 rmse: 1.211886831107334, percentage: 1.423985001193391
# 	Data time: 0.1770005226135254, train_time: 2.461885929107666, overall_time: 2.6418869495391846
# Key: CFM56-5B4 CRUISE, metric: WBE
# 	 rmse: 0.008315859154191224, percentage: 0.4386061717485976
# 	Data time: 0.11506843566894531, train_time: 1.9865503311157227, overall_time: 2.106621503829956
# Key: CFM56-5B4 CRUISE, metric: WBI
# 	 rmse: 0.008163740125388456, percentage: 0.44608408263201416
# 	Data time: 0.11899161338806152, train_time: 1.9049861431121826, overall_time: 2.0289764404296875
# Key: CFM56-5B4 CRUISE, metric: WFMP
# 	 rmse: 13.512906349734957, percentage: 0.8047321334522134
# 	Data time: 0.1259143352508545, train_time: 2.1560633182525635, overall_time: 2.284977912902832
# Key: CFM56-5B4 CRUISE, metric: ZPCN25_D
# 	 rmse: 0.059082986266136, percentage: 1.6880853218896
# 	Data time: 0.12598586082458496, train_time: 3.068321704864502, overall_time: 3.2033097743988037
# Key: CFM56-5B4 CRUISE, metric: ZT49_D
# 	 rmse: 1.8478372165989312, percentage: 5.98005099503718
# 	Data time: 0.1660001277923584, train_time: 2.388572931289673, overall_time: 2.559579849243164
# Key: CFM56-5B4 CRUISE, metric: ZTNAC_D
# 	 rmse: 2.566939527765222, percentage: 4.0745071869289236
# 	Data time: 0.11209487915039062, train_time: 2.152738571166992, overall_time: 2.2688331604003906
# Key: CFM56-5B4 CRUISE, metric: ZWF36_D
# 	 rmse: 9.186230632166339, percentage: 2.19305704937097
# 	Data time: 0.11900544166564941, train_time: 2.091297149658203, overall_time: 2.2132818698883057
# Key: CFM56-5B4 TAKEOFF, metric: BRAT
# 	 rmse: 0.03726999835289688, percentage: 2.1279899239185545
# 	Data time: 0.08099889755249023, train_time: 0.37000155448913574, overall_time: 0.4529993534088135
# Key: CFM56-5B4 TAKEOFF, metric: DELFN
# 	 rmse: 0.3712933067045835, percentage: 1.1045787310931465
# 	Data time: 0.11996841430664062, train_time: 2.0849809646606445, overall_time: 2.2189488410949707
# Key: CFM56-5B4 TAKEOFF, metric: DELN1
# 	 rmse: 0.1407915537987485, percentage: 1.136181753952794
# 	Data time: 0.21861648559570312, train_time: 1.9525046348571777, overall_time: 2.1731419563293457
# Key: CFM56-5B4 TAKEOFF, metric: EGTHDM
# 	 rmse: 3.2599751231511056, percentage: 2.972797044044644
# 	Data time: 0.09098196029663086, train_time: 1.1140058040618896, overall_time: 1.206984519958496
# Key: CFM56-5B4 TAKEOFF, metric: EGTHDM_D
# 	 rmse: 3.1804906957921597, percentage: 11.368797320964331
# 	Data time: 0.09002542495727539, train_time: 1.1344377994537354, overall_time: 1.226444959640503
# Key: CFM56-5B4 TAKEOFF, metric: PCN12
# 	 rmse: 0.09342217971108095, percentage: 0.5434299919732863
# 	Data time: 0.08697724342346191, train_time: 1.181483268737793, overall_time: 1.270442247390747
# Key: CFM56-5B4 TAKEOFF, metric: PCN12I
# 	 rmse: 0.08318872112855817, percentage: 0.46999285705274985
# 	Data time: 0.0950005054473877, train_time: 1.286179542541504, overall_time: 1.3841805458068848
# Key: CFM56-5B4 TAKEOFF, metric: PCN1AR
# 	 rmse: 0.11701177284358151, percentage: 0.8107800674183905
# 	Data time: 0.1060037612915039, train_time: 1.215010404586792, overall_time: 1.3249990940093994
# Key: CFM56-5B4 TAKEOFF, metric: PCN1BR
# 	 rmse: 1.5623261583253132, percentage: 1.6254245814303847
# 	Data time: 0.08900618553161621, train_time: 1.114638090133667, overall_time: 1.2056450843811035
# Key: CFM56-5B4 TAKEOFF, metric: PCN1K
# 	 rmse: 0.09791176359639753, percentage: 0.6785108903325752
# 	Data time: 0.09590744972229004, train_time: 1.281378984451294, overall_time: 1.3792657852172852
# Key: CFM56-5B4 TAKEOFF, metric: SLOATL
# 	 rmse: 1.0845337288272747, percentage: 3.053606416010875
# 	Data time: 0.10128164291381836, train_time: 1.2090232372283936, overall_time: 1.3142824172973633
# Key: CFM56-5B4 TAKEOFF, metric: SLOATL_D
# 	 rmse: 1.056475360961453, percentage: 11.1530292729471
# 	Data time: 0.10100007057189941, train_time: 1.2619998455047607, overall_time: 1.365999460220337
# Key: CFM56-5B4 TAKEOFF, metric: ZPCN25_D
# 	 rmse: 0.07948949040974622, percentage: 7.226327334863759
# 	Data time: 0.08799886703491211, train_time: 1.2287063598632812, overall_time: 1.3186845779418945
# Key: CFM56-5B4 TAKEOFF, metric: ZT49_D
# 	 rmse: 2.8724451568373204, percentage: 10.839415686178567
# 	Data time: 0.09097647666931152, train_time: 1.1629538536071777, overall_time: 1.2559092044830322
# Key: CFM56-7B26 CRUISE, metric: BRAT
# 	 rmse: 0.03161689827273577, percentage: 3.1616898272735767
# 	Data time: 0.1420149803161621, train_time: 0.4970123767852783, overall_time: 0.642998456954956
# Key: CFM56-7B26 CRUISE, metric: DEGT
# 	 rmse: 1.5798440062879087, percentage: 1.9535985063304144
# 	Data time: 0.16299915313720703, train_time: 3.0453059673309326, overall_time: 3.210322141647339
# Key: CFM56-7B26 CRUISE, metric: DPOIL
# 	 rmse: 0.0424015818898006, percentage: 0.1560045607902223
# 	Data time: 0.10999774932861328, train_time: 1.7529573440551758, overall_time: 1.8669557571411133
# Key: CFM56-7B26 CRUISE, metric: EGTC
# 	 rmse: 0.9284555515405712, percentage: 0.4462762811227822
# 	Data time: 0.11598396301269531, train_time: 1.6939990520477295, overall_time: 1.8129851818084717
# Key: CFM56-7B26 CRUISE, metric: EGTHDM
# 	 rmse: 2.8112069621412057, percentage: 2.763481186083154
# 	Data time: 0.11700654029846191, train_time: 1.7491095066070557, overall_time: 1.8701038360595703
# Key: CFM56-7B26 CRUISE, metric: GEGTMC
# 	 rmse: 1.583921172943812, percentage: 1.9586402267372294
# 	Data time: 0.11406278610229492, train_time: 1.752537488937378, overall_time: 1.8705999851226807
# Key: CFM56-7B26 CRUISE, metric: GN2MC
# 	 rmse: 0.07647223778731661, percentage: 4.037660229810677
# 	Data time: 0.10899949073791504, train_time: 1.712001085281372, overall_time: 1.8240001201629639
# Key: CFM56-7B26 CRUISE, metric: GPCN25
# 	 rmse: 0.07647223811150032, percentage: 4.0376625365307115
# 	Data time: 0.11000442504882812, train_time: 1.8369975090026855, overall_time: 1.9500031471252441
# Key: CFM56-7B26 CRUISE, metric: GWFM
# 	 rmse: 0.48424935234265976, percentage: 6.710120737018528
# 	Data time: 0.12899518013000488, train_time: 1.813000202178955, overall_time: 1.945997714996338
# Key: CFM56-7B26 CRUISE, metric: PCN12
# 	 rmse: 0.02331971877121788, percentage: 0.14236704893240662
# 	Data time: 0.10699796676635742, train_time: 1.7704298496246338, overall_time: 1.881427526473999
# Key: CFM56-7B26 CRUISE, metric: PCN12I
# 	 rmse: 0.02331971877121788, percentage: 0.14236704893240662
# 	Data time: 0.10798335075378418, train_time: 1.7639312744140625, overall_time: 1.874913215637207
# Key: CFM56-7B26 CRUISE, metric: PCN1K
# 	 rmse: 0.058184095033425746, percentage: 0.357759673975279
# 	Data time: 0.10897445678710938, train_time: 1.7030024528503418, overall_time: 1.8169779777526855
# Key: CFM56-7B26 CRUISE, metric: PCN2C
# 	 rmse: 0.05595228369621463, percentage: 0.4711837839377186
# 	Data time: 0.10200119018554688, train_time: 1.8277606964111328, overall_time: 1.932781457901001
# Key: CFM56-7B26 CRUISE, metric: SLOATL
# 	 rmse: 0.8323431175802568, percentage: 2.710973772146009
# 	Data time: 0.11431384086608887, train_time: 1.7437973022460938, overall_time: 1.8631300926208496
# Key: CFM56-7B26 CRUISE, metric: WBI
# 	 rmse: 0.03161689827273577, percentage: 3.1616898272735767
# 	Data time: 0.11600303649902344, train_time: 0.44699740409851074, overall_time: 0.5659999847412109
# Key: CFM56-7B26 CRUISE, metric: WFMP
# 	 rmse: 13.297265917494352, percentage: 0.8739146930345727
# 	Data time: 0.13501620292663574, train_time: 1.8283612728118896, overall_time: 1.966378927230835
# Key: CFM56-7B26 CRUISE, metric: ZPCN25_D
# 	 rmse: 1.027050324665919, percentage: 1.4177945120307045
# 	Data time: 0.10500073432922363, train_time: 0.6233112812042236, overall_time: 0.732306957244873
# Key: CFM56-7B26 CRUISE, metric: ZT49_D
# 	 rmse: 12.6764413185092, percentage: 1.6505782966808855
# 	Data time: 0.12311792373657227, train_time: 1.5149493217468262, overall_time: 1.6400694847106934
# Key: CFM56-7B26 CRUISE, metric: ZWF36_D
# 	 rmse: 209.30929719804575, percentage: 1.7033634212080546
# 	Data time: 0.10703921318054199, train_time: 0.50594162940979, overall_time: 0.6149802207946777
# Key: CFM56-7B26 TAKEOFF, metric: BRAT
# 	 rmse: 0.025688315434353536, percentage: 2.5688315434353535
# 	Data time: 0.11100339889526367, train_time: 2.464989423751831, overall_time: 2.580991506576538
# Key: CFM56-7B26 TAKEOFF, metric: DELFN
# 	 rmse: 0.2483565521024984, percentage: 0.5932249237645549
# 	Data time: 0.17299866676330566, train_time: 2.614528179168701, overall_time: 2.791525363922119
# Key: CFM56-7B26 TAKEOFF, metric: DELN1
# 	 rmse: 0.10327076191209288, percentage: 0.6115695403753383
# 	Data time: 0.11497831344604492, train_time: 1.856644868850708, overall_time: 1.9746437072753906
# Key: CFM56-7B26 TAKEOFF, metric: EGTHDM
# 	 rmse: 2.2467450914711673, percentage: 2.064210963855156
# 	Data time: 0.11408305168151855, train_time: 1.8196358680725098, overall_time: 1.937699794769287
# Key: CFM56-7B26 TAKEOFF, metric: EGTHDM_D
# 	 rmse: 2.97834162217338, percentage: 5.114996441970369
# 	Data time: 0.11198115348815918, train_time: 1.7630977630615234, overall_time: 1.8780603408813477
# Key: CFM56-7B26 TAKEOFF, metric: PCN12
# 	 rmse: 0.0701082791008556, percentage: 0.3527376636563849
# 	Data time: 0.10498404502868652, train_time: 1.9055914878845215, overall_time: 2.0135796070098877
# Key: CFM56-7B26 TAKEOFF, metric: PCN12I
# 	 rmse: 0.05933962622400439, percentage: 0.30244453648319014
# 	Data time: 0.1250011920928955, train_time: 1.7499980926513672, overall_time: 1.8769986629486084
# Key: CFM56-7B26 TAKEOFF, metric: PCN1AR
# 	 rmse: 0.09754394074139099, percentage: 0.5825766413524286
# 	Data time: 0.10899949073791504, train_time: 1.8812086582183838, overall_time: 1.993187665939331
# Key: CFM56-7B26 TAKEOFF, metric: PCN1BR
# 	 rmse: 1.3592380298977105, percentage: 1.3680303637817965
# 	Data time: 0.11200237274169922, train_time: 1.7569048404693604, overall_time: 1.8729112148284912
# Key: CFM56-7B26 TAKEOFF, metric: PCN1K
# 	 rmse: 0.09664783605923137, percentage: 0.5775720923922054
# 	Data time: 0.11399221420288086, train_time: 2.122992515563965, overall_time: 2.2399885654449463
# Key: CFM56-7B26 TAKEOFF, metric: SLOATL
# 	 rmse: 0.7212606719008662, percentage: 2.1236677977078906
# 	Data time: 0.1159827709197998, train_time: 2.01493239402771, overall_time: 2.1349165439605713
# Key: CFM56-7B26 TAKEOFF, metric: SLOATL_D
# 	 rmse: 0.9579373864613078, percentage: 5.271775877653939
# 	Data time: 0.12600040435791016, train_time: 1.9910016059875488, overall_time: 2.1200008392333984
# Key: CFM56-7B26 TAKEOFF, metric: ZPCN25_D
# 	 rmse: 0.3874441468506652, percentage: 0.6539141718998569
# 	Data time: 0.11299920082092285, train_time: 1.8639404773712158, overall_time: 1.97994065284729
# Key: CFM56-7B26 TAKEOFF, metric: ZT49_D
# 	 rmse: 8.397256477888096, percentage: 1.5184912256578835
# 	Data time: 0.12499165534973145, train_time: 0.6639413833618164, overall_time: 0.7899389266967773
# Key: CFM56-7B27_B1 CRUISE, metric: BRAT
# 	 rmse: 0.0384115726701968, percentage: 3.84115726701968
# 	Data time: 0.18199896812438965, train_time: 2.265115261077881, overall_time: 2.4501147270202637
# Key: CFM56-7B27_B1 CRUISE, metric: DEGT
# 	 rmse: 2.3939516491092414, percentage: 4.697339611706415
# 	Data time: 0.14200043678283691, train_time: 2.855360984802246, overall_time: 2.9993600845336914
# Key: CFM56-7B27_B1 CRUISE, metric: DPOIL
# 	 rmse: 0.1289660199144039, percentage: 0.8908544581864474
# 	Data time: 0.08098006248474121, train_time: 1.0677392482757568, overall_time: 1.1497187614440918
# Key: CFM56-7B27_B1 CRUISE, metric: EGTC
# 	 rmse: 1.5502421311368066, percentage: 1.0221231367614734
# 	Data time: 0.0869894027709961, train_time: 0.9229974746704102, overall_time: 1.011986494064331
# Key: CFM56-7B27_B1 CRUISE, metric: EGTHDM
# 	 rmse: 3.220494887406094, percentage: 4.489796913006944
# 	Data time: 0.07105422019958496, train_time: 1.3746984004974365, overall_time: 1.450754165649414
# Key: CFM56-7B27_B1 CRUISE, metric: GEGTMC
# 	 rmse: 2.3837977876580627, percentage: 4.6774149496039525
# 	Data time: 0.10499906539916992, train_time: 1.1201145648956299, overall_time: 1.2291107177734375
# Key: CFM56-7B27_B1 CRUISE, metric: GN2MC
# 	 rmse: 0.10508223521659758, percentage: 7.0774366646605085
# 	Data time: 0.08197903633117676, train_time: 0.9330191612243652, overall_time: 1.0159802436828613
# Key: CFM56-7B27_B1 CRUISE, metric: GPCN25
# 	 rmse: 0.10525231855979077, percentage: 7.0888725330190745
# 	Data time: 0.07899999618530273, train_time: 1.060063362121582, overall_time: 1.1420650482177734
# Key: CFM56-7B27_B1 CRUISE, metric: GWFM
# 	 rmse: 0.5079759459462287, percentage: 8.432661539264332
# 	Data time: 0.13100290298461914, train_time: 1.2070553302764893, overall_time: 1.3400583267211914
# Key: CFM56-7B27_B1 CRUISE, metric: PCN12
# 	 rmse: 0.08499538140080388, percentage: 0.7906547107051524
# 	Data time: 0.0760030746459961, train_time: 0.9584481716156006, overall_time: 1.0374560356140137
# Key: CFM56-7B27_B1 CRUISE, metric: PCN12I
# 	 rmse: 0.08499538140080388, percentage: 0.7906547107051524
# 	Data time: 0.07596302032470703, train_time: 1.020017385482788, overall_time: 1.097984790802002
# Key: CFM56-7B27_B1 CRUISE, metric: PCN1K
# 	 rmse: 0.11567636011816922, percentage: 1.3396974374882475
# 	Data time: 0.07800102233886719, train_time: 0.9020419120788574, overall_time: 0.9819996356964111
# Key: CFM56-7B27_B1 CRUISE, metric: PCN2C
# 	 rmse: 0.0700335756261167, percentage: 0.899298036655338
# 	Data time: 0.07198214530944824, train_time: 1.0629982948303223, overall_time: 1.1369836330413818
# Key: CFM56-7B27_B1 CRUISE, metric: SLOATL
# 	 rmse: 0.95752936648418, percentage: 4.445814553384149
# 	Data time: 0.07602047920227051, train_time: 1.2068626880645752, overall_time: 1.286881685256958
# Key: CFM56-7B27_B1 CRUISE, metric: WBI
# 	 rmse: 0.0384115726701968, percentage: 3.84115726701968
# 	Data time: 0.12400674819946289, train_time: 0.8603222370147705, overall_time: 0.9853293895721436
# Key: CFM56-7B27_B1 CRUISE, metric: WFMP
# 	 rmse: 15.123134989541327, percentage: 1.3890103424587914
# 	Data time: 0.0841073989868164, train_time: 1.0068912506103516, overall_time: 1.0940122604370117
# Key: CFM56-7B27_B1 CRUISE, metric: ZPCN25_D
# 	 rmse: 1.6502537481509132, percentage: 2.898232760203283
# 	Data time: 0.10499429702758789, train_time: 1.0619914531707764, overall_time: 1.168989658355713
# Key: CFM56-7B27_B1 CRUISE, metric: ZT49_D
# 	 rmse: 15.9014687328738, percentage: 4.240391662099681
# 	Data time: 0.08298277854919434, train_time: 0.3560028076171875, overall_time: 0.44098806381225586
# Key: CFM56-7B27_B1 CRUISE, metric: ZWF36_D
# 	 rmse: 534.4243879491083, percentage: 61.2872004528794
# 	Data time: 0.07595229148864746, train_time: 0.30179929733276367, overall_time: 0.379746675491333
# Key: CFM56-7B27_B1 TAKEOFF, metric: BRAT
# 	 rmse: 0.004856488464197553, percentage: 0.48564884641975525
# 	Data time: 0.27710509300231934, train_time: 1.604421615600586, overall_time: 1.8835251331329346
# Key: CFM56-7B27_B1 TAKEOFF, metric: DELFN
# 	 rmse: 0.3478614018454627, percentage: 0.9026575832698792
# 	Data time: 0.1159815788269043, train_time: 1.4379966259002686, overall_time: 1.5559790134429932
# Key: CFM56-7B27_B1 TAKEOFF, metric: DELN1
# 	 rmse: 0.16178636975515578, percentage: 0.9168581370230865
# 	Data time: 0.0709841251373291, train_time: 0.9459950923919678, overall_time: 1.0190060138702393
# Key: CFM56-7B27_B1 TAKEOFF, metric: EGTHDM
# 	 rmse: 4.466709516096587, percentage: 6.201038945366141
# 	Data time: 0.06700372695922852, train_time: 1.0266697406768799, overall_time: 1.0946540832519531
# Key: CFM56-7B27_B1 TAKEOFF, metric: EGTHDM_D
# 	 rmse: 2.916786216063451, percentage: 6.27012650376092
# 	Data time: 0.07800054550170898, train_time: 1.0041136741638184, overall_time: 1.0851144790649414
# Key: CFM56-7B27_B1 TAKEOFF, metric: PCN12
# 	 rmse: 0.1571407562414127, percentage: 0.8458187958128792
# 	Data time: 0.07000041007995605, train_time: 0.9220294952392578, overall_time: 0.9930074214935303
# Key: CFM56-7B27_B1 TAKEOFF, metric: PCN12I
# 	 rmse: 0.11223950745273935, percentage: 0.5870266205122424
# 	Data time: 0.06698012351989746, train_time: 1.0310018062591553, overall_time: 1.0999913215637207
# Key: CFM56-7B27_B1 TAKEOFF, metric: PCN1AR
# 	 rmse: 0.2210158178659419, percentage: 1.2515552029414143
# 	Data time: 0.07200145721435547, train_time: 1.0072426795959473, overall_time: 1.0812406539916992
# Key: CFM56-7B27_B1 TAKEOFF, metric: PCN1BR
# 	 rmse: 0.1853529344080932, percentage: 0.18119684768040642
# 	Data time: 0.0892939567565918, train_time: 1.0706446170806885, overall_time: 1.1629421710968018
# Key: CFM56-7B27_B1 TAKEOFF, metric: PCN1K
# 	 rmse: 0.21483061899877182, percentage: 1.2357156929042923
# 	Data time: 0.08278751373291016, train_time: 1.0812222957611084, overall_time: 1.1660096645355225
# Key: CFM56-7B27_B1 TAKEOFF, metric: SLOATL
# 	 rmse: 1.4007327813114112, percentage: 6.322273513221018
# 	Data time: 0.07498502731323242, train_time: 1.1070010662078857, overall_time: 1.184995174407959
# Key: CFM56-7B27_B1 TAKEOFF, metric: SLOATL_D
# 	 rmse: 0.9049076142663847, percentage: 6.387577427240289
# 	Data time: 0.07202410697937012, train_time: 1.0721566677093506, overall_time: 1.146176815032959
# Key: CFM56-7B27_B1 TAKEOFF, metric: ZPCN25_D
# 	 rmse: 0.06306722620080554, percentage: 0.23798953283322843
# 	Data time: 0.08295655250549316, train_time: 1.044177532196045, overall_time: 1.1291301250457764
# Key: CFM56-7B27_B1 TAKEOFF, metric: ZT49_D
# 	 rmse: 2.816320064859979, percentage: 1.5223351701945833
# 	Data time: 0.07104945182800293, train_time: 1.3065826892852783, overall_time: 1.3796207904815674

# %% [markdown]
# ### Evaluate models on test dataset

# %%
get_overall_score(2)
# Out:
#              rmse percent error
# BRAT        0.021         1.12%
# DEGT        1.857          0.7%
# DELFN       0.328         0.78%
# DELN1       0.150         0.81%
# DELVSV      0.020         0.11%
# DPOIL       0.063         0.19%
# EGTC        1.016         0.26%
# EGTHDM      3.198         0.93%
# EGTHDM_D    3.633         5.32%
# GEGTMC      1.842         0.64%
# GN2MC       0.075         0.79%
# GPCN25      0.076         0.84%
# GWFM        0.479         0.68%
# PCN12       0.090         0.17%
# PCN12I      0.080         0.15%
# PCN1AR      0.167         0.78%
# PCN1BR      1.778         1.74%
# PCN1K       0.117         0.24%
# PCN2C       0.051         0.31%
# SLOATL      0.971         0.83%
# SLOATL_D    1.106         5.56%
# WBE         0.179         0.13%
# WBI         0.020         0.98%
# WFMP       14.246         0.45%
# ZPCN25_D    0.360          0.5%
# ZT49_D      5.966         0.78%
# ZTLA_D      0.061         0.92%
# ZTNAC_D     2.121         2.91%
# ZWF36_D   132.495         1.08%

# %% [markdown]
# ### Create submission

# %%
y_valid = predict("X_valid.csv", "models/exp2/")
y_valid
# Out:
# C:\Users\Dim0n\AppData\Local\Temp\ipykernel_5092\1410005440.py:38: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   result = result.fillna(result.mean())
#                                              engine_id      flight_datetime  \
# 0    bf23db5ac85aa359c82cb8a18b0d0ce406fc40272a9b00...  2022-06-07 02:48:28
# 1    0a88b8ae00eb0b817075fb953711648d5d3dd8687e5794...  2022-04-11 14:05:20
# 2    2d1eecee1d07af92b614c41744cf604226df549b1ca451...  2022-04-21 09:34:31
# 3    b89b5e1fea12a0ab78c29ca87649bf2687f1558dd0e67c...  2022-06-28 17:14:01
# 4    ed163ff56745c53c98f72a1f2d2b989f7472e9231378c7...  2022-07-02 00:10:12
# ..                                                 ...                  ...
# 600  364a94e57c5e7705c650bdadda955186d3a8f9d96a3d9e...  2022-04-18 07:42:30
# 601  8795a3b0ee5404d35e8c3d2ad94a55b22f7b2e568efba0...  2022-06-27 06:55:12
# 602  75f7a52561c81524430f1f2b83d40b61d4d1bdf83ab837...  2022-04-27 01:09:59
# 603  e2f2eecb0976a1b21fbc21d709416039de60230cc5ba33...  2022-04-24 17:28:49
# 604  8795a3b0ee5404d35e8c3d2ad94a55b22f7b2e568efba0...  2022-03-21 15:19:56
#
#     flight_phase      BRAT       DEGT        EGTC    GPCN25      GWFM  \
# 0         CRUISE  1.000000  11.733448  766.179141  0.487207  4.423521
# 1         CRUISE  0.999999  14.583947  676.838089  0.071364  2.561371
# 2         CRUISE  1.000001  18.166474  712.984819  0.311030  1.000648
# 3         CRUISE  1.000005  18.482742  761.128886 -0.368831  3.319905
# 4         CRUISE  1.000000  13.654651  855.203761 -0.566104  0.511675
# ..           ...       ...        ...         ...       ...       ...
# 600      TAKEOFF  1.000019   2.747740  660.400365  0.013040 -1.615732
# 601      TAKEOFF  1.000009   2.747740  660.400365  0.013040 -1.615732
# 602      TAKEOFF  0.999979   2.747740  660.400365  0.013040 -1.615732
# 603      TAKEOFF  1.000007   2.747740  660.400365  0.013040 -1.615732
# 604      TAKEOFF  1.000009   2.747740  660.400365  0.013040 -1.615732
#
#          PCN12     PCN12I  ...     DPOIL     GEGTMC    GN2MC       WBE  \
# 0    91.437901  91.440539  ... -19.15243  94.461648  2.64092  1.567022
# 1    87.289403  87.301037  ... -19.15243  94.461648  2.64092  1.567022
# 2    88.407462  88.411817  ... -19.15243  94.461648  2.64092  1.567022
# 3    90.988659  91.002532  ... -19.15243  94.461648  2.64092  1.567022
# 4    98.552016  98.518963  ... -19.15243  94.461648  2.64092  1.567022
# ..         ...        ...  ...       ...        ...      ...       ...
# 600  87.899997  88.389134  ... -19.15243  94.461648  2.64092  1.567022
# 601  91.821588  92.436771  ... -19.15243  94.461648  2.64092  1.567022
# 602  92.371090  92.826112  ... -19.15243  94.461648  2.64092  1.567022
# 603  87.658277  88.087893  ... -19.15243  94.461648  2.64092  1.567022
# 604  92.116684  92.438799  ... -19.15243  94.461648  2.64092  1.567022
#
#       ZTNAC_D      DELFN      DELN1     PCN1AR     PCN1BR  VSVNOM
# 0   -0.072951  17.323733   6.888370  90.153133  90.085177     0.0
# 1   -0.072951  17.323733   6.888370  90.153133  90.085177     0.0
# 2   -0.072951  17.323733   6.888370  90.153133  90.085177     0.0
# 3   -0.072951  17.323733   6.888370  90.153133  90.085177     0.0
# 4   -0.072951  17.323733   6.888370  90.153133  90.085177     0.0
# ..        ...        ...        ...        ...        ...     ...
# 600 -0.072951  26.037438  12.055206  89.546539  89.965146     0.0
# 601 -0.072951  23.302760  10.130065  89.610982  90.226392     0.0
# 602 -0.072951  21.469482   9.775971  90.887515  91.363158     0.0
# 603 -0.072951  31.405499  14.563255  87.375261  87.894542     0.0
# 604 -0.072951  15.473151   8.173826  93.990974  94.236693     0.0
#
# [28676 rows x 33 columns]

# %%
y_valid.to_csv("y_valid_RealityX.csv", index=False)

# %% [markdown]
# ### Create archive with weights (models)

# %%
import shutil

shutil.make_archive("weights_RealityX", "zip", base_dir="models/exp2/")
# Out:
# 'weights_RealityX.zip'
