# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from Encoder import Encoder
import os
import time
from catboost import CatBoostRegressor, Pool
import pickle
from sklearn.metrics import mean_squared_error
import pprint

# %%
class CombinedMetric(tf.keras.callbacks.Callback):
    def __init__(self, patience):
        super(CombinedMetric, self).__init__()
        self.patience = patience
        self.wait = 0
        self.best = np.Inf
        self.best_weights = None

    def on_epoch_end(self, epoch, logs={}):
        accuracy = logs['val_root_mean_squared_error']
        self.wait += 1
        if (accuracy <= self.best):
            self.best = accuracy
            self.best_weights = self.model.get_weights()
            self.wait = 0
        else:
            if(self.wait >= self.patience and epoch > 0):
                self.model.stop_training = True
                if self.best_weights is not None:
                    self.model.set_weights(self.best_weights)
        logs['best'] = self.best

    def on_train_end(self, logs=None):
        if self.wait < self.patience and self.best_weights is not None:
            self.model.set_weights(self.best_weights)

# %%
data = pd.read_csv('./X_train.csv')
flight_phase_encoder = Encoder(data['flight_phase'].unique())
aircraft_grp_encoder = Encoder(data['aircraft_grp'].unique())

# %%
def get_engine_targets():
    data = pd.read_csv('./X_train.csv')
    y = pd.read_csv('./y_train.csv')
    y = y.drop(columns=['VSVNOM'])
    y['engine_type'] = data[data['engine_id'] == y['engine_id']]['engine_type']
    # y['n1_modifier'] = data[data['engine_id'] == y['engine_id']]['n1_modifier']
    # y = y.astype({'n1_modifier': 'int32'})
    targets = {}
    for engine, df in y.groupby(['engine_type', 'flight_phase']):
        df = df.drop(columns=['flight_datetime', 'engine_id', 'flight_phase', 'engine_type'])
        size = df.shape[0]
        key = ' '.join([str(x) for x in engine]).replace('/', '_')
        for column in df.columns:
            if df[column].isna().sum() / size < 0.3 and (df[column].max() - df[column].min()) > 0.0001:
                engine_targets = targets.get(key, [])
                engine_targets.append(column)
                targets[key] = engine_targets

    return targets

# %%
def generate_dataset(key: str, metric:str, x: pd.DataFrame, y: pd.DataFrame, empty:list = None):
    engine_type, flight_phase = key.split(' ')
    x['target'] = y[y['engine_id'] == x['engine_id']][metric]
    x = x[x['engine_type'] == engine_type] 
    # x = x[x['n1_modifier'] == n1_modifier]
    x = x[x['flight_phase'] == flight_phase]
    if(empty is None):
        empty = []
        size = x.shape[0]
        for column in x.drop(columns=['target', 'flight_phase']).columns:
            if (x[column].isna().sum() / size) > 0.7:
                empty.append(column)
    x = x.drop(columns=empty)
    x = x[x['target'].notna()]
    x['aircraft_grp'] = x['aircraft_grp'].apply(aircraft_grp_encoder.encode_single)
    x = x.fillna(-100)
    return x.drop(columns=['target', 'engine_id', 'aircraft_id', 'flight_datetime', 'engine_family', 'engine_type', 'manufacturer', 'ac_manufacturer', 'aircraft_type', 'aircraft_family', 'flight_phase']), x['target'], empty

# %%
def generate_full_dataset(key: str, metric:str, x: pd.DataFrame, y: pd.DataFrame, x_te, y_te):
    x_train, y_train, empty = generate_dataset(key, metric, x, y)
    x_test, y_test, _ = generate_dataset(key, metric, x_te, y_te, empty)
    return x_train, y_train, x_test, y_test, empty

# %%
def create_model(shape: int):
    model = tf.keras.models.Sequential([
        tf.keras.layers.InputLayer(shape),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dense(32, activation='relu'),
        tf.keras.layers.Dropout(0.1),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dense(8, activation='relu'),
        tf.keras.layers.BatchNormalization(),
        tf.keras.layers.Dense(1),
    ])
    scheduler = tf.keras.optimizers.schedules.PolynomialDecay(0.1, 3000, 0.001)
    model.compile(optimizer=tf.keras.optimizers.Adam(scheduler), loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# %%
def train_model(key: str, metric:str, x: pd.DataFrame, y: pd.DataFrame, x_te, y_te):
    t_start = time.time()
    x_train, y_train, x_test, y_test, empty = generate_full_dataset(
        key,
        metric,
        x,
        y,
        x_te,
        y_te
    )
    train_pool = Pool(x_train, y_train)
    val_pool = Pool(x_test, y_test)
    test_pool = Pool(x_test)
    t_data = time.time() - t_start
    # model = create_model(x_train.shape[1])
    t_train = time.time()
    # model.fit(x_train, y_train, epochs=200, batch_size=32, validation_data=(x_test, y_test), callbacks=[CombinedMetric(20)], verbose=0)
    # loss, rmse = model.evaluate(x_test, y_test)
    model = CatBoostRegressor(iterations=3200, loss_function='RMSE', logging_level='Silent', use_best_model=True, early_stopping_rounds=150, max_depth=4)
    model.fit(train_pool, eval_set=val_pool)
    t_train = time.time() - t_train
    rmse = mean_squared_error(y_test, model.predict(test_pool), squared=False)
    print(f'Key: {key}, metric: {metric} \n\t rmse: {rmse}, percentage: {rmse / max(y_train.max() - y_train.min(), 0.0001) * 100}\n\tData time: {t_data}, train_time: {t_train}, overall_time: {time.time() - t_start}')
    return model

# %%
def train_all_models():
    index = len(list(os.listdir('models'))) + 1
    # index = len(list(os.listdir('models')))
    os.mkdir(os.path.join('models', f'exp{index}'))
    targets = get_engine_targets()
    x = pd.read_csv('X_train.csv')
    x['engine_type'] = x['engine_type'].map(lambda x: x.replace('/', '_'))
    x = x.astype({'n1_modifier': 'int32'})
    y = pd.read_csv('y_train.csv')
    x_te = pd.read_csv('X_test.csv')
    x_te['engine_type'] = x_te['engine_type'].map(lambda x: x.replace('/', '_'))
    x_te = x_te.astype({'n1_modifier': 'int32'})
    y_te = pd.read_csv('y_test.csv')
    for key, metrics in targets.items():
        os.mkdir(os.path.join('models', f'exp{index}', key))
        for metric in metrics:
            # print(metric)
            model = train_model(key, metric, x, y, x_te, y_te)
            model.save_model(os.path.join('models', f'exp{index}', key, f'{metric}.cbm'))
            # model.save(os.path.join('models', f'exp{index}', engine, f'{metric}.h5'))

# %%
def evaluate_all_models(exp_index: int):
    targets = get_engine_targets()
    x = pd.read_csv('X_train.csv')
    x['engine_type'] = x['engine_type'].map(lambda x: x.replace('/', '_'))
    x = x.astype({'n1_modifier': 'int32'})
    y = pd.read_csv('y_train.csv')
    x_te = pd.read_csv('X_test.csv')
    x_te['engine_type'] = x_te['engine_type'].map(lambda x: x.replace('/', '_'))
    x_te = x_te.astype({'n1_modifier': 'int32'})
    y_te = pd.read_csv('y_test.csv')
    scores = {}
    for key, metrics in targets.items():
        for metric in metrics:
            # model = tf.keras.models.load_model(os.path.join('models', f'exp{exp_index}', engine, f'{metric}.h5'))
            model = CatBoostRegressor().load_model(os.path.join('models', f'exp{exp_index}', key, f'{metric}.cbm'))
            
            x_train, y_train, x_test, y_test, empty = generate_full_dataset(
                key,
                metric,
                x,
                y,
                x_te,
                y_te
            )
            # loss, rmse = model.evaluate(x_test, y_test)
            test_pool = Pool(x_test)
            rmse = mean_squared_error(y_test, model.predict(test_pool), squared=False)
            engine_scores = scores.get(key, {})
            engine_scores[metric] = {'rmse': rmse, 'percent': rmse / (max(y_train.max() - y_train.min(), 0.01)) * 100}
            scores[key] = engine_scores
    return scores

# %%
train_all_models()
# Out:
# Key: CF34-8E5 CRUISE, metric: BRAT
# 	 rmse: 0.0043982504347780185, percentage: 0.4398250434778018
# 	Data time: 0.06699800491333008, train_time: 4.723588228225708, overall_time: 4.794586181640625
# Key: CF34-8E5 CRUISE, metric: DEGT
# 	 rmse: 1.8937983512889813, percentage: 1.670900759719552
# 	Data time: 0.05399775505065918, train_time: 4.340362548828125, overall_time: 4.397361516952515
# Key: CF34-8E5 CRUISE, metric: EGTC
# 	 rmse: 1.2967567167720633, percentage: 0.3810842094709215
# 	Data time: 0.0540010929107666, train_time: 4.37437891960144, overall_time: 4.432382106781006
# Key: CF34-8E5 CRUISE, metric: GPCN25
# 	 rmse: 0.07727147858254628, percentage: 2.861068427084742
# 	Data time: 0.05299949645996094, train_time: 4.434455633163452, overall_time: 4.490455865859985
# Key: CF34-8E5 CRUISE, metric: GWFM
# 	 rmse: 0.707303827798308, percentage: 3.8380779564747303
# 	Data time: 0.05500006675720215, train_time: 4.40537428855896, overall_time: 4.464374303817749
# Key: CF34-8E5 CRUISE, metric: PCN12
# 	 rmse: 0.0784205863078242, percentage: 0.302377604114909
# 	Data time: 0.05100059509277344, train_time: 4.276395082473755, overall_time: 4.3313963413238525
# Key: CF34-8E5 CRUISE, metric: PCN12I
# 	 rmse: 0.0688604232512871, percentage: 0.2651937647409368
# 	Data time: 0.051999568939208984, train_time: 4.250209808349609, overall_time: 4.306210994720459
# Key: CF34-8E5 CRUISE, metric: PCN1K
# 	 rmse: 0.08525403972128513, percentage: 0.3254757092525443
# 	Data time: 0.052001237869262695, train_time: 4.459685802459717, overall_time: 4.5146870613098145
# Key: CF34-8E5 CRUISE, metric: PCN2C
# 	 rmse: 0.0664304344642401, percentage: 0.5482755753531023
# 	Data time: 0.05299973487854004, train_time: 4.3015711307525635, overall_time: 4.358571767807007
# Key: CF34-8E5 CRUISE, metric: WBI
# 	 rmse: 0.00439825055378027, percentage: 0.439825055378027
# 	Data time: 0.051999807357788086, train_time: 4.40028977394104, overall_time: 4.455289840698242
# Key: CF34-8E5 CRUISE, metric: WFMP
# 	 rmse: 10.2366182698756, percentage: 0.905667658718854
# 	Data time: 0.053000688552856445, train_time: 4.333386421203613, overall_time: 4.389389514923096
# Key: CF34-8E5 CRUISE, metric: ZPCN25_D
# 	 rmse: 0.0737722135369316, percentage: 4.674607120022429
# 	Data time: 0.05331587791442871, train_time: 4.39126992225647, overall_time: 4.448586463928223
# Key: CF34-8E5 CRUISE, metric: ZT49_D
# 	 rmse: 5.147444891956417, percentage: 8.596985205772722
# 	Data time: 0.05299997329711914, train_time: 4.267010927200317, overall_time: 4.324009656906128
# Key: CF34-8E5 CRUISE, metric: ZTLA_D
# 	 rmse: 0.060678553301261526, percentage: 0.9180721850179624
# 	Data time: 0.05399942398071289, train_time: 1.7005481719970703, overall_time: 1.7575464248657227
# Key: CF34-8E5 CRUISE, metric: ZWF36_D
# 	 rmse: 13.240786511111539, percentage: 7.297810364369976
# 	Data time: 0.05300021171569824, train_time: 4.4928154945373535, overall_time: 4.54881477355957
# Key: CF34-8E5 TAKEOFF, metric: BRAT
# 	 rmse: 0.005070733945720212, percentage: 0.5070733945720213
# 	Data time: 0.05500006675720215, train_time: 3.7367923259735107, overall_time: 3.795793294906616
# Key: CF34-8E5 TAKEOFF, metric: EGTHDM
# 	 rmse: 1.2822161842897943, percentage: 0.992130261869535
# 	Data time: 0.05699944496154785, train_time: 4.274616479873657, overall_time: 4.3356170654296875
# Key: CF34-8E5 TAKEOFF, metric: EGTHDM_D
# 	 rmse: 5.501635117000775, percentage: 8.049726503744049
# 	Data time: 0.05458784103393555, train_time: 4.506710529327393, overall_time: 4.565298318862915
# Key: CF34-8E5 TAKEOFF, metric: PCN12
# 	 rmse: 0.055505799505719766, percentage: 0.3010583710699215
# 	Data time: 0.05299806594848633, train_time: 4.4328179359436035, overall_time: 4.489817380905151
# Key: CF34-8E5 TAKEOFF, metric: PCN1K
# 	 rmse: 0.04698308636999373, percentage: 0.4487648798814586
# 	Data time: 0.053539276123046875, train_time: 4.316955327987671, overall_time: 4.373495101928711
# Key: CF34-8E5 TAKEOFF, metric: SLOATL
# 	 rmse: 0.363473548857865, percentage: 0.9850087181725569
# 	Data time: 0.053999900817871094, train_time: 4.473991870880127, overall_time: 4.531994342803955
# Key: CF34-8E5 TAKEOFF, metric: SLOATL_D
# 	 rmse: 1.5556164636490721, percentage: 7.820284180745815
# 	Data time: 0.0540013313293457, train_time: 4.500155448913574, overall_time: 4.558156728744507
# Key: CF34-8E5 TAKEOFF, metric: ZPCN25_D
# 	 rmse: 0.06568145991478193, percentage: 8.757527988637591
# 	Data time: 0.053513526916503906, train_time: 4.392327308654785, overall_time: 4.4498419761657715
# Key: CF34-8E5 TAKEOFF, metric: ZT49_D
# 	 rmse: 5.147224344595235, percentage: 7.58338761634657
# 	Data time: 0.05300116539001465, train_time: 4.358770132064819, overall_time: 4.415772914886475
# Key: CF34-8E5 TAKEOFF, metric: ZWF36_D
# 	 rmse: 24.53633277963408, percentage: 6.694770199081604
# 	Data time: 0.05300140380859375, train_time: 4.509269714355469, overall_time: 4.566270351409912
# Key: CFM56-5B3 CRUISE, metric: BRAT
# 	 rmse: 0.020550866373769523, percentage: 1.1608173704149343
# 	Data time: 0.03699898719787598, train_time: 0.8915579319000244, overall_time: 0.9315571784973145
# Key: CFM56-5B3 CRUISE, metric: DEGT
# 	 rmse: 2.1004664962603474, percentage: 3.4188841191368122
# 	Data time: 0.04800081253051758, train_time: 3.155818223953247, overall_time: 3.206819534301758
# Key: CFM56-5B3 CRUISE, metric: DELVSV
# 	 rmse: 0.01659276655235607, percentage: 0.12290938529255821
# 	Data time: 0.03700900077819824, train_time: 2.8814446926116943, overall_time: 2.921454906463623
# Key: CFM56-5B3 CRUISE, metric: DPOIL
# 	 rmse: 0.061792663502152866, percentage: 0.40715202707210935
# 	Data time: 0.03799939155578613, train_time: 2.9891932010650635, overall_time: 3.0301926136016846
# Key: CFM56-5B3 CRUISE, metric: EGTC
# 	 rmse: 0.8993001440324836, percentage: 0.46385010308115715
# 	Data time: 0.03703927993774414, train_time: 3.049417734146118, overall_time: 3.0894582271575928
# Key: CFM56-5B3 CRUISE, metric: EGTHDM
# 	 rmse: 3.2908338762208733, percentage: 3.923874644409226
# 	Data time: 0.037000417709350586, train_time: 2.79946231842041, overall_time: 2.8394651412963867
# Key: CFM56-5B3 CRUISE, metric: GEGTMC
# 	 rmse: 2.1013161517369867, percentage: 3.4202668623898704
# 	Data time: 0.03799891471862793, train_time: 2.848466157913208, overall_time: 2.8894646167755127
# Key: CFM56-5B3 CRUISE, metric: GN2MC
# 	 rmse: 0.06195013884412132, percentage: 3.6270678104581116
# 	Data time: 0.03800010681152344, train_time: 2.92354154586792, overall_time: 2.96454119682312
# Key: CFM56-5B3 CRUISE, metric: GPCN25
# 	 rmse: 0.061950128223663754, percentage: 3.6270587113309882
# 	Data time: 0.037000417709350586, train_time: 2.9669077396392822, overall_time: 3.005908727645874
# Key: CFM56-5B3 CRUISE, metric: GWFM
# 	 rmse: 0.3336134056658, percentage: 2.703960184601249
# 	Data time: 0.03746843338012695, train_time: 3.02691650390625, overall_time: 3.06638503074646
# Key: CFM56-5B3 CRUISE, metric: PCN12
# 	 rmse: 0.059331989853035824, percentage: 0.13515259155032885
# 	Data time: 0.03699946403503418, train_time: 2.8990604877471924, overall_time: 2.9390597343444824
# Key: CFM56-5B3 CRUISE, metric: PCN12I
# 	 rmse: 0.059331989853035824, percentage: 0.13515259155032885
# 	Data time: 0.03800010681152344, train_time: 2.973243474960327, overall_time: 3.0132436752319336
# Key: CFM56-5B3 CRUISE, metric: PCN1K
# 	 rmse: 0.13530147050777716, percentage: 0.7521106132220106
# 	Data time: 0.03800082206726074, train_time: 2.9567019939422607, overall_time: 2.997708797454834
# Key: CFM56-5B3 CRUISE, metric: PCN2C
# 	 rmse: 0.04307723964812662, percentage: 0.48526054115139133
# 	Data time: 0.03800034523010254, train_time: 3.055999755859375, overall_time: 3.097001075744629
# Key: CFM56-5B3 CRUISE, metric: SLOATL
# 	 rmse: 0.9519133812766247, percentage: 3.8643127275219644
# 	Data time: 0.03744697570800781, train_time: 2.6915290355682373, overall_time: 2.731976270675659
# Key: CFM56-5B3 CRUISE, metric: WBE
# 	 rmse: 0.3516912355250232, percentage: 0.3030479800248276
# 	Data time: 0.03800010681152344, train_time: 2.421999931335449, overall_time: 2.463001012802124
# Key: CFM56-5B3 CRUISE, metric: WBI
# 	 rmse: 0.016205727017150034, percentage: 0.9153812647044013
# 	Data time: 0.037000179290771484, train_time: 2.9730420112609863, overall_time: 3.0130422115325928
# Key: CFM56-5B3 CRUISE, metric: WFMP
# 	 rmse: 22.203052292991853, percentage: 1.224648749138774
# 	Data time: 0.03699898719787598, train_time: 2.848693370819092, overall_time: 2.888693332672119
# Key: CFM56-5B3 CRUISE, metric: ZPCN25_D
# 	 rmse: 0.03511604658881752, percentage: 5.016490596520786
# 	Data time: 0.037000179290771484, train_time: 2.098275661468506, overall_time: 2.1382763385772705
# Key: CFM56-5B3 CRUISE, metric: ZT49_D
# 	 rmse: 1.5081326722500064, percentage: 5.043917864662366
# 	Data time: 0.03801155090332031, train_time: 2.538613796234131, overall_time: 2.578627586364746
# Key: CFM56-5B3 CRUISE, metric: ZTNAC_D
# 	 rmse: 1.7594071916612344, percentage: 2.410146837892102
# 	Data time: 0.037999868392944336, train_time: 2.947854518890381, overall_time: 2.9888546466827393
# Key: CFM56-5B3 CRUISE, metric: ZWF36_D
# 	 rmse: 4.496413914218818, percentage: 2.2661547234932526
# 	Data time: 0.03751373291015625, train_time: 2.898359775543213, overall_time: 2.938875675201416
# Key: CFM56-5B3 TAKEOFF, metric: BRAT
# 	 rmse: 0.028779306567610165, percentage: 2.764176633952789
# 	Data time: 0.03199911117553711, train_time: 0.990889310836792, overall_time: 1.024888277053833
# Key: CFM56-5B3 TAKEOFF, metric: DELFN
# 	 rmse: 0.4800079079298788, percentage: 1.5784371695435881
# 	Data time: 0.032999515533447266, train_time: 1.9716403484344482, overall_time: 2.0066418647766113
# Key: CFM56-5B3 TAKEOFF, metric: DELN1
# 	 rmse: 0.254409797232908, percentage: 1.9362084469001148
# 	Data time: 0.03699970245361328, train_time: 1.8747060298919678, overall_time: 1.913705825805664
# Key: CFM56-5B3 TAKEOFF, metric: EGTHDM
# 	 rmse: 6.299026944651339, percentage: 4.801322809198388
# 	Data time: 0.030998706817626953, train_time: 1.7713537216186523, overall_time: 1.8033525943756104
# Key: CFM56-5B3 TAKEOFF, metric: EGTHDM_D
# 	 rmse: 3.6597692555084933, percentage: 9.737451552115783
# 	Data time: 0.03131723403930664, train_time: 0.6319103240966797, overall_time: 0.6642293930053711
# Key: CFM56-5B3 TAKEOFF, metric: PCN12
# 	 rmse: 0.22340315267908775, percentage: 1.33067298199135
# 	Data time: 0.03100132942199707, train_time: 1.7556402683258057, overall_time: 1.788557529449463
# Key: CFM56-5B3 TAKEOFF, metric: PCN12I
# 	 rmse: 0.18502386662476095, percentage: 1.0883756924302153
# 	Data time: 0.030999183654785156, train_time: 1.7627644538879395, overall_time: 1.7957634925842285
# Key: CFM56-5B3 TAKEOFF, metric: PCN1AR
# 	 rmse: 0.2928556864947921, percentage: 2.095962264499877
# 	Data time: 0.03099989891052246, train_time: 1.8126072883605957, overall_time: 1.8456089496612549
# Key: CFM56-5B3 TAKEOFF, metric: PCN1BR
# 	 rmse: 3.9969690572810754, percentage: 4.006602548475039
# 	Data time: 0.03300023078918457, train_time: 1.7777931690216064, overall_time: 1.8127946853637695
# Key: CFM56-5B3 TAKEOFF, metric: PCN1K
# 	 rmse: 0.2970168795313499, percentage: 2.109491182436278
# 	Data time: 0.030999422073364258, train_time: 1.7465784549713135, overall_time: 1.7795777320861816
# Key: CFM56-5B3 TAKEOFF, metric: SLOATL
# 	 rmse: 1.824890180473225, percentage: 4.8357697495061895
# 	Data time: 0.03099966049194336, train_time: 1.8043336868286133, overall_time: 1.8373327255249023
# Key: CFM56-5B3 TAKEOFF, metric: SLOATL_D
# 	 rmse: 1.0619906176209881, percentage: 9.574178523433542
# 	Data time: 0.031594276428222656, train_time: 0.6153883934020996, overall_time: 0.6479835510253906
# Key: CFM56-5B3 TAKEOFF, metric: ZPCN25_D
# 	 rmse: 0.08102191145683497, percentage: 11.574483082428495
# 	Data time: 0.03099656105041504, train_time: 0.7642872333526611, overall_time: 0.7959978580474854
# Key: CFM56-5B3 TAKEOFF, metric: ZT49_D
# 	 rmse: 3.4997258117771173, percentage: 9.523063433407122
# 	Data time: 0.034590721130371094, train_time: 0.5770022869110107, overall_time: 0.6125924587249756
# Key: CFM56-5B4 CRUISE, metric: BRAT
# 	 rmse: 0.007980039222897379, percentage: 0.43604603393478136
# 	Data time: 0.04900002479553223, train_time: 3.19152569770813, overall_time: 3.2445266246795654
# Key: CFM56-5B4 CRUISE, metric: DEGT
# 	 rmse: 1.754782365598685, percentage: 0.8302202908628925
# 	Data time: 0.05156898498535156, train_time: 3.9846041202545166, overall_time: 4.040174961090088
# Key: CFM56-5B4 CRUISE, metric: DELVSV
# 	 rmse: 0.023698258438737275, percentage: 0.13021020547832762
# 	Data time: 0.05100107192993164, train_time: 3.3906753063201904, overall_time: 3.445676803588867
# Key: CFM56-5B4 CRUISE, metric: DPOIL
# 	 rmse: 0.047725422834707217, percentage: 0.2713817163214264
# 	Data time: 0.051000356674194336, train_time: 3.94303035736084, overall_time: 3.9980316162109375
# Key: CFM56-5B4 CRUISE, metric: EGTC
# 	 rmse: 0.8529190877973318, percentage: 0.38861721933763577
# 	Data time: 0.051999568939208984, train_time: 4.1709229946136475, overall_time: 4.226921558380127
# Key: CFM56-5B4 CRUISE, metric: EGTHDM
# 	 rmse: 3.3817468126987724, percentage: 1.211475252987395
# 	Data time: 0.05158591270446777, train_time: 4.026237964630127, overall_time: 4.081824064254761
# Key: CFM56-5B4 CRUISE, metric: GEGTMC
# 	 rmse: 1.7430121591677559, percentage: 0.824650571314903
# 	Data time: 0.051000356674194336, train_time: 3.9844696521759033, overall_time: 4.039471626281738
# Key: CFM56-5B4 CRUISE, metric: GN2MC
# 	 rmse: 0.07184525882390261, percentage: 0.8484925175370543
# 	Data time: 0.05201148986816406, train_time: 4.059612989425659, overall_time: 4.115303993225098
# Key: CFM56-5B4 CRUISE, metric: GPCN25
# 	 rmse: 0.07194262460870292, percentage: 0.8496430265855581
# 	Data time: 0.05099916458129883, train_time: 3.9940924644470215, overall_time: 4.048091650009155
# Key: CFM56-5B4 CRUISE, metric: GWFM
# 	 rmse: 0.3954773518413973, percentage: 0.557107380841504
# 	Data time: 0.05301237106323242, train_time: 3.8915975093841553, overall_time: 3.9486095905303955
# Key: CFM56-5B4 CRUISE, metric: PCN12
# 	 rmse: 0.08060499822370067, percentage: 0.20458120597711313
# 	Data time: 0.05099964141845703, train_time: 4.051239013671875, overall_time: 4.1062397956848145
# Key: CFM56-5B4 CRUISE, metric: PCN12I
# 	 rmse: 0.08060499822370067, percentage: 0.20458120597711313
# 	Data time: 0.05100131034851074, train_time: 4.0345985889434814, overall_time: 4.088600158691406
# Key: CFM56-5B4 CRUISE, metric: PCN1K
# 	 rmse: 0.10214654300099645, percentage: 0.27304536865286316
# 	Data time: 0.0510096549987793, train_time: 3.985586404800415, overall_time: 4.0395941734313965
# Key: CFM56-5B4 CRUISE, metric: PCN2C
# 	 rmse: 0.04088187246887171, percentage: 0.3967766601818947
# 	Data time: 0.05152010917663574, train_time: 3.983487844467163, overall_time: 4.039009094238281
# Key: CFM56-5B4 CRUISE, metric: SLOATL
# 	 rmse: 1.0665591911833467, percentage: 1.25322286879073
# 	Data time: 0.05200052261352539, train_time: 3.984494686126709, overall_time: 4.040494918823242
# Key: CFM56-5B4 CRUISE, metric: WBE
# 	 rmse: 0.007120905464718353, percentage: 0.37558032517778317
# 	Data time: 0.05219721794128418, train_time: 3.64980149269104, overall_time: 3.704998731613159
# Key: CFM56-5B4 CRUISE, metric: WBI
# 	 rmse: 0.008012801132412381, percentage: 0.4378364557868457
# 	Data time: 0.05137753486633301, train_time: 2.955078363418579, overall_time: 3.0114567279815674
# Key: CFM56-5B4 CRUISE, metric: WFMP
# 	 rmse: 12.958693171431792, percentage: 0.7717271571858022
# 	Data time: 0.05200028419494629, train_time: 4.034940004348755, overall_time: 4.089940547943115
# Key: CFM56-5B4 CRUISE, metric: ZPCN25_D
# 	 rmse: 0.05694498730000408, percentage: 1.6269996371429736
# 	Data time: 0.05300092697143555, train_time: 4.09930419921875, overall_time: 4.1563074588775635
# Key: CFM56-5B4 CRUISE, metric: ZT49_D
# 	 rmse: 1.767415648675957, percentage: 5.719787226692148
# 	Data time: 0.051999807357788086, train_time: 3.992640495300293, overall_time: 4.048561096191406
# Key: CFM56-5B4 CRUISE, metric: ZTNAC_D
# 	 rmse: 2.4833066310832845, percentage: 3.941756557275055
# 	Data time: 0.051999807357788086, train_time: 4.068262815475464, overall_time: 4.123263835906982
# Key: CFM56-5B4 CRUISE, metric: ZWF36_D
# 	 rmse: 8.778028936374698, percentage: 2.0956058049632373
# 	Data time: 0.052001237869262695, train_time: 4.034876108169556, overall_time: 4.089876890182495
# Key: CFM56-5B4 TAKEOFF, metric: BRAT
# 	 rmse: 0.0373110929476317, percentage: 2.130336285265158
# 	Data time: 0.03699851036071777, train_time: 0.5330893993377686, overall_time: 0.5720853805541992
# Key: CFM56-5B4 TAKEOFF, metric: DELFN
# 	 rmse: 0.3477367567909341, percentage: 1.0344991914335375
# 	Data time: 0.039002418518066406, train_time: 2.5717720985412598, overall_time: 2.613776683807373
# Key: CFM56-5B4 TAKEOFF, metric: DELN1
# 	 rmse: 0.13461647186664497, percentage: 1.0863491096561875
# 	Data time: 0.037000417709350586, train_time: 2.372654676437378, overall_time: 2.4126553535461426
# Key: CFM56-5B4 TAKEOFF, metric: EGTHDM
# 	 rmse: 2.862435879430936, percentage: 2.6102778701312164
# 	Data time: 0.037000417709350586, train_time: 2.3321030139923096, overall_time: 2.3721044063568115
# Key: CFM56-5B4 TAKEOFF, metric: EGTHDM_D
# 	 rmse: 3.175395268561508, percentage: 11.350583502723756
# 	Data time: 0.03699946403503418, train_time: 2.164299964904785, overall_time: 2.2032999992370605
# Key: CFM56-5B4 TAKEOFF, metric: PCN12
# 	 rmse: 0.08580382458183193, percentage: 0.4991145769450671
# 	Data time: 0.0369412899017334, train_time: 2.3323631286621094, overall_time: 2.3713061809539795
# Key: CFM56-5B4 TAKEOFF, metric: PCN12I
# 	 rmse: 0.07872948667729354, percentage: 0.4447994376614469
# 	Data time: 0.03800010681152344, train_time: 2.4310929775238037, overall_time: 2.4720940589904785
# Key: CFM56-5B4 TAKEOFF, metric: PCN1AR
# 	 rmse: 0.10273015346316004, percentage: 0.7118220562481745
# 	Data time: 0.036010026931762695, train_time: 2.35768461227417, overall_time: 2.395693302154541
# Key: CFM56-5B4 TAKEOFF, metric: PCN1BR
# 	 rmse: 1.5693984953271007, percentage: 1.6327825523314081
# 	Data time: 0.04300379753112793, train_time: 2.3345346450805664, overall_time: 2.3795387744903564
# Key: CFM56-5B4 TAKEOFF, metric: PCN1K
# 	 rmse: 0.08665294622691654, percentage: 0.6004893133855179
# 	Data time: 0.03700900077819824, train_time: 2.3246915340423584, overall_time: 2.3637003898620605
# Key: CFM56-5B4 TAKEOFF, metric: SLOATL
# 	 rmse: 0.9535326757659939, percentage: 2.684760666451142
# 	Data time: 0.03601264953613281, train_time: 2.316629648208618, overall_time: 2.354644536972046
# Key: CFM56-5B4 TAKEOFF, metric: SLOATL_D
# 	 rmse: 1.0541010458910645, percentage: 11.12796403578043
# 	Data time: 0.03600025177001953, train_time: 1.4280195236206055, overall_time: 1.4660208225250244
# Key: CFM56-5B4 TAKEOFF, metric: ZPCN25_D
# 	 rmse: 0.07902209514669942, percentage: 7.183836797458995
# 	Data time: 0.03601193428039551, train_time: 1.2282295227050781, overall_time: 1.2662415504455566
# Key: CFM56-5B4 TAKEOFF, metric: ZT49_D
# 	 rmse: 2.8389308661695796, percentage: 10.712946664790866
# 	Data time: 0.03707695007324219, train_time: 2.172183036804199, overall_time: 2.211259603500366
# Key: CFM56-7B26 CRUISE, metric: BRAT
# 	 rmse: 0.031470369709805615, percentage: 3.1470369709805617
# 	Data time: 0.04699993133544922, train_time: 0.589052677154541, overall_time: 0.6380536556243896
# Key: CFM56-7B26 CRUISE, metric: DEGT
# 	 rmse: 1.357840861557283, percentage: 1.6790745595228667
# 	Data time: 0.05064558982849121, train_time: 3.5682833194732666, overall_time: 3.621929407119751
# Key: CFM56-7B26 CRUISE, metric: DPOIL
# 	 rmse: 0.03347502204516833, percentage: 0.12316182271623385
# 	Data time: 0.0449986457824707, train_time: 3.4733707904815674, overall_time: 3.5213680267333984
# Key: CFM56-7B26 CRUISE, metric: EGTC
# 	 rmse: 0.7531534551723807, percentage: 0.36201466244818586
# 	Data time: 0.04699969291687012, train_time: 3.497619390487671, overall_time: 3.5486204624176025
# Key: CFM56-7B26 CRUISE, metric: EGTHDM
# 	 rmse: 2.541385610308075, percentage: 2.4982405832260652
# 	Data time: 0.04600048065185547, train_time: 3.4326512813568115, overall_time: 3.48165225982666
# Key: CFM56-7B26 CRUISE, metric: GEGTMC
# 	 rmse: 1.3539701995381064, percentage: 1.674288180446492
# 	Data time: 0.04699993133544922, train_time: 3.52846360206604, overall_time: 3.5784637928009033
# Key: CFM56-7B26 CRUISE, metric: GN2MC
# 	 rmse: 0.06420495976881768, percentage: 3.3899598091550263
# 	Data time: 0.04600095748901367, train_time: 3.365326166152954, overall_time: 3.4143285751342773
# Key: CFM56-7B26 CRUISE, metric: GPCN25
# 	 rmse: 0.06416758739020333, percentage: 3.387988504890137
# 	Data time: 0.04600048065185547, train_time: 3.436856508255005, overall_time: 3.4868571758270264
# Key: CFM56-7B26 CRUISE, metric: GWFM
# 	 rmse: 0.46332589590607076, percentage: 6.420189695818267
# 	Data time: 0.0449986457824707, train_time: 3.4994568824768066, overall_time: 3.5484538078308105
# Key: CFM56-7B26 CRUISE, metric: PCN12
# 	 rmse: 0.017345031009389875, percentage: 0.10589153765849446
# 	Data time: 0.0455324649810791, train_time: 3.423352003097534, overall_time: 3.4728844165802
# Key: CFM56-7B26 CRUISE, metric: PCN12I
# 	 rmse: 0.017345031009389875, percentage: 0.10589153765849446
# 	Data time: 0.04499959945678711, train_time: 3.5153396129608154, overall_time: 3.5643391609191895
# Key: CFM56-7B26 CRUISE, metric: PCN1K
# 	 rmse: 0.0440732421714942, percentage: 0.2709955141735737
# 	Data time: 0.04600119590759277, train_time: 3.556040048599243, overall_time: 3.605041742324829
# Key: CFM56-7B26 CRUISE, metric: PCN2C
# 	 rmse: 0.045312972464208436, percentage: 0.3815883180581569
# 	Data time: 0.04700040817260742, train_time: 3.4647750854492188, overall_time: 3.514777421951294
# Key: CFM56-7B26 CRUISE, metric: SLOATL
# 	 rmse: 0.7416333696852414, percentage: 2.4155286098957762
# 	Data time: 0.045899391174316406, train_time: 3.440915107727051, overall_time: 3.490816831588745
# Key: CFM56-7B26 CRUISE, metric: WBI
# 	 rmse: 0.031470369709805615, percentage: 3.1470369709805617
# 	Data time: 0.04599952697753906, train_time: 0.5492720603942871, overall_time: 0.597273588180542
# Key: CFM56-7B26 CRUISE, metric: WFMP
# 	 rmse: 12.17699770893754, percentage: 0.800289118147837
# 	Data time: 0.04599928855895996, train_time: 3.5400989055633545, overall_time: 3.5895605087280273
# Key: CFM56-7B26 CRUISE, metric: ZPCN25_D
# 	 rmse: 1.0061122146553487, percentage: 1.3888904391217765
# 	Data time: 0.04600071907043457, train_time: 0.9245171546936035, overall_time: 0.9715123176574707
# Key: CFM56-7B26 CRUISE, metric: ZT49_D
# 	 rmse: 12.688717795039828, percentage: 1.6521767962291445
# 	Data time: 0.04600811004638672, train_time: 1.2412333488464355, overall_time: 1.2902421951293945
# Key: CFM56-7B26 CRUISE, metric: ZWF36_D
# 	 rmse: 209.19329095522946, percentage: 1.702419359987219
# 	Data time: 0.046000003814697266, train_time: 0.5568726062774658, overall_time: 0.6048746109008789
# Key: CFM56-7B26 TAKEOFF, metric: BRAT
# 	 rmse: 0.0253066611304342, percentage: 2.53066611304342
# 	Data time: 0.04801607131958008, train_time: 1.1970982551574707, overall_time: 1.2481155395507812
# Key: CFM56-7B26 TAKEOFF, metric: DELFN
# 	 rmse: 0.2004731900650428, percentage: 0.478850635855545
# 	Data time: 0.04999852180480957, train_time: 4.060883522033691, overall_time: 4.114881992340088
# Key: CFM56-7B26 TAKEOFF, metric: DELN1
# 	 rmse: 0.07967990772200038, percentage: 0.47186448168333833
# 	Data time: 0.047000885009765625, train_time: 3.514514684677124, overall_time: 3.565516471862793
# Key: CFM56-7B26 TAKEOFF, metric: EGTHDM
# 	 rmse: 1.8662023339210023, percentage: 1.7145849491672294
# 	Data time: 0.04801630973815918, train_time: 3.5419294834136963, overall_time: 3.593947410583496
# Key: CFM56-7B26 TAKEOFF, metric: EGTHDM_D
# 	 rmse: 2.950808298216915, percentage: 5.067710780371159
# 	Data time: 0.051833391189575195, train_time: 4.036088705062866, overall_time: 4.091923475265503
# Key: CFM56-7B26 TAKEOFF, metric: PCN12
# 	 rmse: 0.06729291347250353, percentage: 0.33857263911406554
# 	Data time: 0.05147838592529297, train_time: 3.926565408706665, overall_time: 3.981044054031372
# Key: CFM56-7B26 TAKEOFF, metric: PCN12I
# 	 rmse: 0.055355259721330576, percentage: 0.28213686087479783
# 	Data time: 0.04627037048339844, train_time: 3.647012948989868, overall_time: 3.6962835788726807
# Key: CFM56-7B26 TAKEOFF, metric: PCN1AR
# 	 rmse: 0.08310357500325588, percentage: 0.4963322297807553
# 	Data time: 0.04700064659118652, train_time: 3.7139358520507812, overall_time: 3.764937162399292
# Key: CFM56-7B26 TAKEOFF, metric: PCN1BR
# 	 rmse: 1.4039638090096855, percentage: 1.4130454549749
# 	Data time: 0.04600095748901367, train_time: 3.5480434894561768, overall_time: 3.598045587539673
# Key: CFM56-7B26 TAKEOFF, metric: PCN1K
# 	 rmse: 0.08621574949946191, percentage: 0.5152294439892964
# 	Data time: 0.04799914360046387, train_time: 3.5497946739196777, overall_time: 3.6017940044403076
# Key: CFM56-7B26 TAKEOFF, metric: SLOATL
# 	 rmse: 0.6063449457877966, percentage: 1.7853118655129796
# 	Data time: 0.04659295082092285, train_time: 3.5397651195526123, overall_time: 3.5903584957122803
# Key: CFM56-7B26 TAKEOFF, metric: SLOATL_D
# 	 rmse: 0.949119058009616, percentage: 5.223246347572032
# 	Data time: 0.04599952697753906, train_time: 3.5487189292907715, overall_time: 3.5977184772491455
# Key: CFM56-7B26 TAKEOFF, metric: ZPCN25_D
# 	 rmse: 0.4318521088018525, percentage: 0.7288643186529156
# 	Data time: 0.04700016975402832, train_time: 1.2152338027954102, overall_time: 1.2652366161346436
# Key: CFM56-7B26 TAKEOFF, metric: ZT49_D
# 	 rmse: 8.331825492386585, percentage: 1.5066592210463987
# 	Data time: 0.046998023986816406, train_time: 0.5641036033630371, overall_time: 0.6131010055541992
# Key: CFM56-7B27_B1 CRUISE, metric: BRAT
# 	 rmse: 0.03769105004166873, percentage: 3.7691050041668728
# 	Data time: 0.032009124755859375, train_time: 0.8646159172058105, overall_time: 0.8986246585845947
# Key: CFM56-7B27_B1 CRUISE, metric: DEGT
# 	 rmse: 2.1782789054600076, percentage: 4.274153068951507
# 	Data time: 0.03399991989135742, train_time: 2.076525926589966, overall_time: 2.1125240325927734
# Key: CFM56-7B27_B1 CRUISE, metric: DPOIL
# 	 rmse: 0.10895108224053283, percentage: 0.7525979122456938
# 	Data time: 0.03199934959411621, train_time: 1.9279122352600098, overall_time: 1.9619126319885254
# Key: CFM56-7B27_B1 CRUISE, metric: EGTC
# 	 rmse: 1.2759169094523561, percentage: 0.8412519357734821
# 	Data time: 0.03312277793884277, train_time: 1.8921892642974854, overall_time: 1.9283115863800049
# Key: CFM56-7B27_B1 CRUISE, metric: EGTHDM
# 	 rmse: 3.0669323519390694, percentage: 4.275710376062094
# 	Data time: 0.03300023078918457, train_time: 1.902069091796875, overall_time: 1.9370694160461426
# Key: CFM56-7B27_B1 CRUISE, metric: GEGTMC
# 	 rmse: 2.1685131081874056, percentage: 4.25498995055819
# 	Data time: 0.03299975395202637, train_time: 1.8859457969665527, overall_time: 1.9209465980529785
# Key: CFM56-7B27_B1 CRUISE, metric: GN2MC
# 	 rmse: 0.10320808817103125, percentage: 6.951210219363489
# 	Data time: 0.03300046920776367, train_time: 1.8696999549865723, overall_time: 1.9047002792358398
# Key: CFM56-7B27_B1 CRUISE, metric: GPCN25
# 	 rmse: 0.10318885978459681, percentage: 6.949896057872068
# 	Data time: 0.03200030326843262, train_time: 1.9378471374511719, overall_time: 1.9718477725982666
# Key: CFM56-7B27_B1 CRUISE, metric: GWFM
# 	 rmse: 0.49771000161460427, percentage: 8.262241591980683
# 	Data time: 0.033000946044921875, train_time: 2.01147198677063, overall_time: 2.0464749336242676
# Key: CFM56-7B27_B1 CRUISE, metric: PCN12
# 	 rmse: 0.07448170051166857, percentage: 0.6928530280155215
# 	Data time: 0.03199958801269531, train_time: 1.8703629970550537, overall_time: 1.905362844467163
# Key: CFM56-7B27_B1 CRUISE, metric: PCN12I
# 	 rmse: 0.07448170051166857, percentage: 0.6928530280155215
# 	Data time: 0.03199934959411621, train_time: 1.9626569747924805, overall_time: 1.996656894683838
# Key: CFM56-7B27_B1 CRUISE, metric: PCN1K
# 	 rmse: 0.10970812253300698, percentage: 1.2705767235325616
# 	Data time: 0.033014774322509766, train_time: 1.8107969760894775, overall_time: 1.8458120822906494
# Key: CFM56-7B27_B1 CRUISE, metric: PCN2C
# 	 rmse: 0.0590339029302764, percentage: 0.7580517277130365
# 	Data time: 0.0319976806640625, train_time: 1.8870909214019775, overall_time: 1.921090841293335
# Key: CFM56-7B27_B1 CRUISE, metric: SLOATL
# 	 rmse: 0.9206425951031157, percentage: 4.2745490540967195
# 	Data time: 0.03201556205749512, train_time: 1.8787553310394287, overall_time: 1.9127695560455322
# Key: CFM56-7B27_B1 CRUISE, metric: WBI
# 	 rmse: 0.03769105004166873, percentage: 3.7691050041668728
# 	Data time: 0.03299999237060547, train_time: 0.9216361045837402, overall_time: 0.9566373825073242
# Key: CFM56-7B27_B1 CRUISE, metric: WFMP
# 	 rmse: 13.65487597834495, percentage: 1.2541555684076116
# 	Data time: 0.03300118446350098, train_time: 1.896052598953247, overall_time: 1.9310543537139893
# Key: CFM56-7B27_B1 CRUISE, metric: ZPCN25_D
# 	 rmse: 1.6627837943875257, percentage: 2.920238461163213
# 	Data time: 0.032000064849853516, train_time: 0.9383676052093506, overall_time: 0.972367525100708
# Key: CFM56-7B27_B1 CRUISE, metric: ZT49_D
# 	 rmse: 15.939143915208069, percentage: 4.250438377388818
# 	Data time: 0.03300023078918457, train_time: 0.4031367301940918, overall_time: 0.43713998794555664
# Key: CFM56-7B27_B1 CRUISE, metric: ZWF36_D
# 	 rmse: 534.7222325542318, percentage: 61.32135694429264
# 	Data time: 0.03400444984436035, train_time: 0.4545564651489258, overall_time: 0.48856091499328613
# Key: CFM56-7B27_B1 TAKEOFF, metric: BRAT
# 	 rmse: 0.007044714091368219, percentage: 0.7044714091368219
# 	Data time: 0.03299975395202637, train_time: 1.197633981704712, overall_time: 1.2326343059539795
# Key: CFM56-7B27_B1 TAKEOFF, metric: DELFN
# 	 rmse: 0.2849429010817249, percentage: 0.7393918068972816
# 	Data time: 0.03499960899353027, train_time: 2.05069899559021, overall_time: 2.0876998901367188
# Key: CFM56-7B27_B1 TAKEOFF, metric: DELN1
# 	 rmse: 0.12974803732487872, percentage: 0.7352939803527496
# 	Data time: 0.03352975845336914, train_time: 1.9534761905670166, overall_time: 1.9890077114105225
# Key: CFM56-7B27_B1 TAKEOFF, metric: EGTHDM
# 	 rmse: 4.193469245701952, percentage: 5.821705220606667
# 	Data time: 0.03299999237060547, train_time: 1.9450428485870361, overall_time: 1.9800963401794434
# Key: CFM56-7B27_B1 TAKEOFF, metric: EGTHDM_D
# 	 rmse: 2.8783450686953715, percentage: 6.187490739912286
# 	Data time: 0.03299975395202637, train_time: 1.131671667098999, overall_time: 1.1666700839996338
# Key: CFM56-7B27_B1 TAKEOFF, metric: PCN12
# 	 rmse: 0.15430011841430522, percentage: 0.8305289058840476
# 	Data time: 0.04499936103820801, train_time: 1.5046396255493164, overall_time: 1.5506389141082764
# Key: CFM56-7B27_B1 TAKEOFF, metric: PCN12I
# 	 rmse: 0.09926272531954526, percentage: 0.519156431719939
# 	Data time: 0.03357267379760742, train_time: 1.9032788276672363, overall_time: 1.9388525485992432
# Key: CFM56-7B27_B1 TAKEOFF, metric: PCN1AR
# 	 rmse: 0.18942611954884966, percentage: 1.0726709417611249
# 	Data time: 0.033063650131225586, train_time: 1.9029440879821777, overall_time: 1.9390087127685547
# Key: CFM56-7B27_B1 TAKEOFF, metric: PCN1BR
# 	 rmse: 0.14213855034901995, percentage: 0.13895144060897363
# 	Data time: 0.03358793258666992, train_time: 1.9104621410369873, overall_time: 1.9460508823394775
# Key: CFM56-7B27_B1 TAKEOFF, metric: PCN1K
# 	 rmse: 0.17779196666273162, percentage: 1.0226676453355572
# 	Data time: 0.03255009651184082, train_time: 1.937093734741211, overall_time: 1.971644401550293
# Key: CFM56-7B27_B1 TAKEOFF, metric: SLOATL
# 	 rmse: 1.31378188316764, percentage: 5.9298165309760025
# 	Data time: 0.03256559371948242, train_time: 1.9952337741851807, overall_time: 2.0298001766204834
# Key: CFM56-7B27_B1 TAKEOFF, metric: SLOATL_D
# 	 rmse: 0.9099347766187315, percentage: 6.423063247293816
# 	Data time: 0.03399991989135742, train_time: 0.9630327224731445, overall_time: 0.9990320205688477
# Key: CFM56-7B27_B1 TAKEOFF, metric: ZPCN25_D
# 	 rmse: 0.10463981540145767, percentage: 0.394867227930029
# 	Data time: 0.03300809860229492, train_time: 0.49499964714050293, overall_time: 0.5290086269378662
# Key: CFM56-7B27_B1 TAKEOFF, metric: ZT49_D
# 	 rmse: 2.7964020767625306, percentage: 1.5115686901419085
# 	Data time: 0.034000396728515625, train_time: 1.272202968597412, overall_time: 1.308203935623169

# %%
scores = evaluate_all_models(17)

# %%
def get_overall_score(scores):
    overall_scores = {}
    for key, metrics in scores.items():
        for metric, val in metrics.items():
            overall_score = overall_scores.get(metric, {'score': 0, 'n': 0})
            overall_score['score'] = overall_score['score'] + val['rmse']
            overall_score['n'] = overall_score['n'] + 1
            overall_scores[metric] = overall_score
    result = {}
    y = pd.read_csv('y_train.csv')
    for metric, val in overall_scores.items():
        result[metric] = [val['score'] / val['n'], (val['score'] / val['n']) / max(y[metric].max() - y[metric].min(), 0.0001) * 100]
        result
    return result

# %%
result_scores = pd.DataFrame.from_dict(get_overall_score(scores), orient='index', columns=['rmse', 'percent error'])
result_scores['rmse'] = result_scores['rmse'].apply(lambda x: '%.3f' % x)
result_scores['percent error'] = result_scores['percent error'].apply(lambda x: f'{round(x, 2)}%')
result_scores.sort_index()
# Out:
#              rmse percent error
# BRAT        0.021         1.12%
# DEGT        1.857          0.7%
# DELFN       0.328         0.78%
# DELN1       0.150         0.81%
# DELVSV      0.020         0.11%
# DPOIL       0.063         0.19%
# EGTC        1.016         0.26%
# EGTHDM      3.198         0.93%
# EGTHDM_D    3.633         5.32%
# GEGTMC      1.842         0.64%
# GN2MC       0.075         0.79%
# GPCN25      0.076         0.84%
# GWFM        0.479         0.68%
# PCN12       0.090         0.17%
# PCN12I      0.080         0.15%
# PCN1AR      0.167         0.78%
# PCN1BR      1.778         1.74%
# PCN1K       0.117         0.24%
# PCN2C       0.051         0.31%
# SLOATL      0.971         0.83%
# SLOATL_D    1.106         5.56%
# WBE         0.179         0.13%
# WBI         0.020         0.98%
# WFMP       14.246         0.45%
# ZPCN25_D    0.360          0.5%
# ZT49_D      5.966         0.78%
# ZTLA_D      0.061         0.92%
# ZTNAC_D     2.121         2.91%
# ZWF36_D   132.495         1.08%

# %%
#11 16 17

# %%
def get_engine_targets():
    data = pd.read_csv('./X_train.csv')
    y = pd.read_csv('./y_train.csv')
    y = y.drop(columns=['VSVNOM'])
    y['engine_type'] = data[data['engine_id'] == y['engine_id']]['engine_type']
    # y['n1_modifier'] = data[data['engine_id'] == y['engine_id']]['n1_modifier']
    # y = y.astype({'n1_modifier': 'int32'})
    targets = {}
    for engine, df in y.groupby(['engine_type', 'flight_phase']):
        df = df.drop(columns=['flight_datetime', 'engine_id', 'flight_phase', 'engine_type'])
        size = df.shape[0]
        key = ' '.join([str(x) for x in engine]).replace('/', '_')
        for column in df.columns:
            if df[column].isna().sum() / size < 0.3 and (df[column].max() - df[column].min()) > 0.0001:
                engine_targets = targets.get(key, [])
                engine_targets.append(column)
                targets[key] = engine_targets

    return targets

# %%
import json
targets = get_engine_targets()
with open('app/targets.json', 'w') as f:
    json.dump(targets, f)

# %%
def generate_val_part(key: str, metric:str, x: pd.DataFrame, aircraft_grp_encoder, empty:list = None):
    engine_type, flight_phase = key.split(' ')
    x = x[x['engine_type'] == engine_type] 
    # x = x[x['n1_modifier'] == n1_modifier]
    x = x[x['flight_phase'] == flight_phase]
    if(empty is None):
        empty = []
        size = x.shape[0]
        for column in x.drop(columns=['engine_type', 'flight_phase']).columns:
            if (x[column].isna().sum() / size) > 0.7:
                empty.append(column)
    x = x.drop(columns=empty)
    x['aircraft_grp'] = x['aircraft_grp'].apply(aircraft_grp_encoder.encode_single)
    x = x.fillna(-100)
    return x[['engine_id', 'flight_datetime', 'flight_phase']], x.drop(columns=['engine_id', 'aircraft_id', 'flight_datetime', 'engine_family', 'engine_type', 'manufacturer', 'ac_manufacturer', 'aircraft_type', 'aircraft_family', 'flight_phase']), empty

# %%
def dataframe_to_dict(dataframe: pd.DataFrame):
    result = []
    dataframe = dataframe.reset_index()
    for index, row in dataframe.iterrows():
        asd = {}
        row = row.drop(labels=['index'])
        asd['engine_id'] = row['engine_id']
        asd['flight_phase'] = row['flight_phase']
        asd['flight_datetime'] = row['flight_datetime']
        metrics = {}
        row = row.drop(labels=['engine_id', 'flight_datetime', 'flight_phase'])
        for label in row.keys():
            metrics[label] = None if np.isnan(row[label]) else row[label]
        asd['metrics'] = metrics
        result.append(asd)
    return result

# %%
def predict(filepath: str, model_dir: str):
    x_val = pd.read_csv(filepath)
    x = pd.read_csv('X_train.csv')
    x['engine_type'] = x['engine_type'].map(lambda x: x.replace('/', '_'))
    x = x.astype({'n1_modifier': 'int32'})
    flight_phase_encoder = Encoder(x['flight_phase'].unique())
    aircraft_grp_encoder = Encoder(x['aircraft_grp'].unique())
    targets = get_engine_targets()
    result = None
    for key, metrics in targets.items():
        df = None
        for metric in metrics:
            _, _, empty = generate_val_part(key, metric, x, aircraft_grp_encoder)
            ids, x_val_part, _ = generate_val_part(key, metric, x_val, aircraft_grp_encoder, empty)
            model = CatBoostRegressor().load_model(os.path.join(model_dir, key, f'{metric}.cbm'))
            prediction = model.predict(x_val_part)
            ids[metric] = prediction
            if df is None:
                df = ids
            else:
                df = pd.merge(df, ids, on=['engine_id', 'flight_datetime', 'flight_phase'], how='outer')
        if result is None:
            result = df
        else:
            result = pd.concat((result, df))
    return result

# %%
tmp = predict('X_valid.csv', 'models/exp17')

# %%
tmp.to_csv('y_valid.csv', index=False)

# %%
dataframe_to_dict(tmp)
# Out:
# [{'engine_id': 'bf23db5ac85aa359c82cb8a18b0d0ce406fc40272a9b009ee01d62a88d4cfc61',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-06-07 02:48:28',
#   'metrics': {'BRAT': 1.0000000852432864,
#    'DEGT': 11.733447669504635,
#    'EGTC': 766.1791414645561,
#    'GPCN25': 0.48720686655286943,
#    'GWFM': 4.423521478467699,
#    'PCN12': 91.43790130170532,
#    'PCN12I': 91.44053903293761,
#    'PCN1K': 97.48274691637293,
#    'PCN2C': 89.3778210724457,
#    'WBI': 8.524372461203578e-08,
#    'WFMP': 1793.597118716451,
#    'ZPCN25_D': 0.14028036939800445,
#    'ZT49_D': -2.0620197136883136,
#    'ZTLA_D': -0.013400144113976265,
#    'ZWF36_D': 4.296574907796749,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '0a88b8ae00eb0b817075fb953711648d5d3dd8687e57946ccff881382b6606ae',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-04-11 14:05:20',
#   'metrics': {'BRAT': 0.9999986156347206,
#    'DEGT': 14.58394697865103,
#    'EGTC': 676.8380893826948,
#    'GPCN25': 0.07136448550575392,
#    'GWFM': 2.5613710218497454,
#    'PCN12': 87.28940331833655,
#    'PCN12I': 87.30103722328401,
#    'PCN1K': 97.20677096306248,
#    'PCN2C': 85.10021951705563,
#    'WBI': -1.384362593332203e-06,
#    'WFMP': 1668.212163680133,
#    'ZPCN25_D': 0.011307791160590656,
#    'ZT49_D': 2.8475398872522377,
#    'ZTLA_D': -0.0042123740714237225,
#    'ZWF36_D': 4.9912317731235,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '2d1eecee1d07af92b614c41744cf604226df549b1ca451c8eed06d11b59243d3',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-04-21 09:34:31',
#   'metrics': {'BRAT': 1.0000009475993297,
#    'DEGT': 18.166474099827763,
#    'EGTC': 712.9848185213373,
#    'GPCN25': 0.3110302854700725,
#    'GWFM': 1.00064761328618,
#    'PCN12': 88.40746237326027,
#    'PCN12I': 88.41181686717091,
#    'PCN1K': 95.69277015974862,
#    'PCN2C': 87.1389542093014,
#    'WBI': 9.47597305607159e-07,
#    'WFMP': 1602.2391746590395,
#    'ZPCN25_D': 0.11694859003570238,
#    'ZT49_D': -0.20716154741674336,
#    'ZTLA_D': -0.0015784593330927291,
#    'ZWF36_D': -9.17423508737154,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'b89b5e1fea12a0ab78c29ca87649bf2687f1558dd0e67c93036996e81d7438c5',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-06-28 17:14:01',
#   'metrics': {'BRAT': 1.0000049587934343,
#    'DEGT': 18.482741605622802,
#    'EGTC': 761.1288864740072,
#    'GPCN25': -0.36883059560174947,
#    'GWFM': 3.3199053683765256,
#    'PCN12': 90.98865872902121,
#    'PCN12I': 91.00253185396653,
#    'PCN1K': 96.8558980633835,
#    'PCN2C': 89.11008153082066,
#    'WBI': 4.958795585470119e-06,
#    'WFMP': 1735.7424314011719,
#    'ZPCN25_D': -0.23935430764394355,
#    'ZT49_D': 0.5851695570246083,
#    'ZTLA_D': -0.051458112020165106,
#    'ZWF36_D': 4.2099617396818685,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'ed163ff56745c53c98f72a1f2d2b989f7472e9231378c7806d55744cb383dfa0',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-07-02 00:10:12',
#   'metrics': {'BRAT': 0.9999997949284082,
#    'DEGT': 13.654651487028174,
#    'EGTC': 855.2037612385441,
#    'GPCN25': -0.5661036338810089,
#    'GWFM': 0.5116745649820054,
#    'PCN12': 98.55201611474894,
#    'PCN12I': 98.51896341168445,
#    'PCN1K': 104.86294000540845,
#    'PCN2C': 91.66068727473679,
#    'WBI': -2.0507301353670654e-07,
#    'WFMP': 2251.564047384651,
#    'ZPCN25_D': -0.23548018123516712,
#    'ZT49_D': 9.042705434668733,
#    'ZTLA_D': -0.02119768119204593,
#    'ZWF36_D': -15.814597256379617,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '1aa393e4300d2fec926784afb613d45cd7e2d1307f2c834fc7c0dcc6f8dc5999',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-06-22 15:51:04',
#   'metrics': {'BRAT': 1.0000004559702917,
#    'DEGT': 30.542597485928244,
#    'EGTC': 691.6750732857266,
#    'GPCN25': 0.19820883641165582,
#    'GWFM': 1.5829411261303703,
#    'PCN12': 87.31349292335732,
#    'PCN12I': 87.30934995157675,
#    'PCN1K': 95.57397893327123,
#    'PCN2C': 86.16252435881702,
#    'WBI': 4.559709043689547e-07,
#    'WFMP': 1615.2948347882032,
#    'ZPCN25_D': 0.012743441424608405,
#    'ZT49_D': 9.640969997030231,
#    'ZTLA_D': -0.0010169150937222938,
#    'ZWF36_D': 1.105654089032972,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'bf23db5ac85aa359c82cb8a18b0d0ce406fc40272a9b009ee01d62a88d4cfc61',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-03-28 02:41:07',
#   'metrics': {'BRAT': 1.0000012633591013,
#    'DEGT': 10.022388085908329,
#    'EGTC': 807.8475978190966,
#    'GPCN25': 0.6852795703224432,
#    'GWFM': 4.092952552885095,
#    'PCN12': 96.52998792515193,
#    'PCN12I': 96.5787462929647,
#    'PCN1K': 105.3097689333357,
#    'PCN2C': 89.55799297843504,
#    'WBI': 1.2633585690985036e-06,
#    'WFMP': 2089.3972183869723,
#    'ZPCN25_D': 0.05054247818395331,
#    'ZT49_D': -0.2789279910506057,
#    'ZTLA_D': -0.004872109238667137,
#    'ZWF36_D': 4.458501697943492,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'fa04101dab850b9846d1d0db9424bcbf0818a52508ad36a69f313cfea9b60824',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-07-16 09:30:41',
#   'metrics': {'BRAT': 0.9999988256375014,
#    'DEGT': 16.95244488243874,
#    'EGTC': 767.3785313511959,
#    'GPCN25': 0.4439995656015622,
#    'GWFM': 2.5792704731873988,
#    'PCN12': 91.89383649027715,
#    'PCN12I': 91.90937685962056,
#    'PCN1K': 98.0671334881553,
#    'PCN2C': 89.37648851931314,
#    'WBI': -1.174361849261979e-06,
#    'WFMP': 2007.8541500858491,
#    'ZPCN25_D': 0.15541081340440732,
#    'ZT49_D': 2.804570896293316,
#    'ZTLA_D': -0.016092480136869335,
#    'ZWF36_D': -40.4959684143325,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '8c97da4bc8feab053617a7323564a5bd3ea7a4c12d2ec94dcefc74dd5c2e9053',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-01-21 10:00:44',
#   'metrics': {'BRAT': 0.9999992146761854,
#    'DEGT': 25.733887424546083,
#    'EGTC': 671.1437129240549,
#    'GPCN25': 0.11857348205500161,
#    'GWFM': 2.5649840111536872,
#    'PCN12': 86.73632095593199,
#    'PCN12I': 86.70773266132824,
#    'PCN1K': 96.42997288008661,
#    'PCN2C': 85.08081909693564,
#    'WBI': -7.853182898932484e-07,
#    'WFMP': 1739.9234267260936,
#    'ZPCN25_D': -0.1576323010513629,
#    'ZT49_D': 3.8108403637142985,
#    'ZTLA_D': -0.005254952417562097,
#    'ZWF36_D': 5.1487956261601395,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '2d1eecee1d07af92b614c41744cf604226df549b1ca451c8eed06d11b59243d3',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-04-22 13:53:25',
#   'metrics': {'BRAT': 1.0000003067624643,
#    'DEGT': 16.3388370726272,
#    'EGTC': 754.6267512449264,
#    'GPCN25': 0.846386964249655,
#    'GWFM': 2.964786411467172,
#    'PCN12': 91.22365571036872,
#    'PCN12I': 91.20761696502336,
#    'PCN1K': 98.06820256787073,
#    'PCN2C': 88.63384198196812,
#    'WBI': 3.067648680094709e-07,
#    'WFMP': 1762.6975751667017,
#    'ZPCN25_D': 0.17629751989516015,
#    'ZT49_D': -0.8644710853324775,
#    'ZTLA_D': -0.0013166246329398145,
#    'ZWF36_D': -21.409594144432173,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'ed163ff56745c53c98f72a1f2d2b989f7472e9231378c7806d55744cb383dfa0',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-07-09 21:54:21',
#   'metrics': {'BRAT': 1.0000018798411552,
#    'DEGT': 18.65120592084741,
#    'EGTC': 742.9628094171891,
#    'GPCN25': -0.5363162247664591,
#    'GWFM': 0.09101093011067585,
#    'PCN12': 90.24571298797736,
#    'PCN12I': 90.24156368785656,
#    'PCN1K': 97.06080713169983,
#    'PCN2C': 88.30348649277285,
#    'WBI': 1.8798397288357152e-06,
#    'WFMP': 1775.9263210205024,
#    'ZPCN25_D': -0.3069918938238377,
#    'ZT49_D': 5.642646431789969,
#    'ZTLA_D': -0.01849546831834793,
#    'ZWF36_D': -17.109758686504623,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'a5309e8aa80e39434a3581d5831133fd490ac7dac8ce95ffead76b0b4e0205a5',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-06-01 18:03:00',
#   'metrics': {'BRAT': 1.0000000053524296,
#    'DEGT': 8.597431916981936,
#    'EGTC': 734.3872238315774,
#    'GPCN25': 0.48746443148669366,
#    'GWFM': 2.893746305705521,
#    'PCN12': 90.23131915991091,
#    'PCN12I': 90.23538297826987,
#    'PCN1K': 98.29681596362911,
#    'PCN2C': 87.464853829528,
#    'WBI': 5.356878152000533e-09,
#    'WFMP': 1700.7022207591058,
#    'ZPCN25_D': -0.07339694451546937,
#    'ZT49_D': -0.6767193978563091,
#    'ZTLA_D': 0.011256989152846494,
#    'ZWF36_D': -4.6106843527959676,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '1aa393e4300d2fec926784afb613d45cd7e2d1307f2c834fc7c0dcc6f8dc5999',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-04-29 19:53:23',
#   'metrics': {'BRAT': 1.0000014841797351,
#    'DEGT': 35.588437370285554,
#    'EGTC': 714.2816181980501,
#    'GPCN25': 0.3698059859790228,
#    'GWFM': 2.8844359595211273,
#    'PCN12': 89.06155810698895,
#    'PCN12I': 89.03896123165701,
#    'PCN1K': 97.73139983747583,
#    'PCN2C': 86.49192097692489,
#    'WBI': 1.4841803101040343e-06,
#    'WFMP': 1541.256292458661,
#    'ZPCN25_D': 0.01795740505110379,
#    'ZT49_D': 14.259275016749191,
#    'ZTLA_D': -0.008864522748297868,
#    'ZWF36_D': 11.478894205965329,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '60958ab5f23535a9df5c86ad4a4425e26e7bf00387221e8d826fb598f801f599',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-06-18 00:34:19',
#   'metrics': {'BRAT': 0.9999997701681026,
#    'DEGT': 33.49775745858693,
#    'EGTC': 802.7989929466762,
#    'GPCN25': -0.012255584300486483,
#    'GWFM': 6.505318421453733,
#    'PCN12': 93.83944346009058,
#    'PCN12I': 93.819236482803,
#    'PCN1K': 99.55834548845611,
#    'PCN2C': 90.37376536663872,
#    'WBI': -2.2983486114291907e-07,
#    'WFMP': 1860.671868050168,
#    'ZPCN25_D': -0.005825897666486991,
#    'ZT49_D': 10.58399900961975,
#    'ZTLA_D': -0.003958054191967601,
#    'ZWF36_D': 36.63731415336796,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '74e006acacdc073defc46eb27660e2dfb7398acbb362399974dc5f8d9e508d94',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-02-18 13:58:15',
#   'metrics': {'BRAT': 1.0000001156839362,
#    'DEGT': 16.20902014292857,
#    'EGTC': 640.8941476427292,
#    'GPCN25': 0.2539279230128598,
#    'GWFM': 4.016878664637334,
#    'PCN12': 84.39488177301524,
#    'PCN12I': 84.44396081296266,
#    'PCN1K': 93.57747257345147,
#    'PCN2C': 84.24820324068438,
#    'WBI': 1.1568485721279165e-07,
#    'WFMP': 1602.0386699715534,
#    'ZPCN25_D': -0.020336333230913238,
#    'ZT49_D': -1.7995054857891286,
#    'ZTLA_D': -0.0031870890929366416,
#    'ZWF36_D': 9.727643615188324,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'ed163ff56745c53c98f72a1f2d2b989f7472e9231378c7806d55744cb383dfa0',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-06-30 18:09:43',
#   'metrics': {'BRAT': 0.9999988335065688,
#    'DEGT': 15.465754173917901,
#    'EGTC': 779.1081688581464,
#    'GPCN25': -0.4707866970144535,
#    'GWFM': -0.030121635090799792,
#    'PCN12': 92.11193260183715,
#    'PCN12I': 92.10588143499815,
#    'PCN1K': 97.75255720153919,
#    'PCN2C': 89.88679171275547,
#    'WBI': -1.166493897033008e-06,
#    'WFMP': 1829.6782609529969,
#    'ZPCN25_D': -0.3013445735345284,
#    'ZT49_D': 1.7063743089332404,
#    'ZTLA_D': -0.016483055986219745,
#    'ZWF36_D': -20.30654918430224,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '904ef6e2228fcd5e19e0bfeebb725e197b6a1a2ff819cf637f0255b97cf1279b',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-05-01 10:20:56',
#   'metrics': {'BRAT': 1.0000025332710283,
#    'DEGT': 14.041118131930153,
#    'EGTC': 690.5877727060652,
#    'GPCN25': 0.11601428818877225,
#    'GWFM': 2.007269742397679,
#    'PCN12': 87.29348525256725,
#    'PCN12I': 87.27651541015067,
#    'PCN1K': 95.41278450156167,
#    'PCN2C': 86.20996952253277,
#    'WBI': 2.5332738709934674e-06,
#    'WFMP': 1667.5771770152378,
#    'ZPCN25_D': -0.022760031273166413,
#    'ZT49_D': -3.3111718317194176,
#    'ZTLA_D': 0.0006590681513310147,
#    'ZWF36_D': 6.528472384179633,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '44e8bfbc36a62fad6ace2953e30c032da88adf250d8efe36ed08e38c83f5ac41',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-06-06 15:25:37',
#   'metrics': {'BRAT': 1.000000972199253,
#    'DEGT': 25.504302965038196,
#    'EGTC': 721.3078516240653,
#    'GPCN25': 0.2267584305938492,
#    'GWFM': 0.9967100186335545,
#    'PCN12': 88.812296947449,
#    'PCN12I': 88.80063749767275,
#    'PCN1K': 95.64997351091355,
#    'PCN2C': 87.61530592832558,
#    'WBI': 9.72198263076221e-07,
#    'WFMP': 1724.990918208833,
#    'ZPCN25_D': 0.15580660949368805,
#    'ZT49_D': 3.8990220113253145,
#    'ZTLA_D': 0.00837747820669419,
#    'ZWF36_D': -0.8600956476271105,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '83dd5ba4ee2f515b83c6f09ffd7268f0a389b6303f0bf3a721afe7e634f87dd4',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-04-06 16:19:22',
#   'metrics': {'BRAT': 0.9999985688451605,
#    'DEGT': 37.79247648877718,
#    'EGTC': 689.9286001847145,
#    'GPCN25': 0.46994568298169676,
#    'GWFM': 7.992455939197512,
#    'PCN12': 87.85967064832411,
#    'PCN12I': 87.8539732362494,
#    'PCN1K': 97.5701635015884,
#    'PCN2C': 85.3879449739228,
#    'WBI': -1.431158330313792e-06,
#    'WFMP': 1519.4935632884906,
#    'ZPCN25_D': -0.013807437456976102,
#    'ZT49_D': 8.69913429197561,
#    'ZTLA_D': 0.0034348883968983914,
#    'ZWF36_D': 11.654917026223583,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '60958ab5f23535a9df5c86ad4a4425e26e7bf00387221e8d826fb598f801f599',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-06-27 23:54:19',
#   'metrics': {'BRAT': 1.0000017022808398,
#    'DEGT': 8.913720295456514,
#    'EGTC': 821.4864179712689,
#    'GPCN25': -0.015243964122546194,
#    'GWFM': 5.222134692173476,
#    'PCN12': 95.89881201602185,
#    'PCN12I': 95.92020062315193,
#    'PCN1K': 102.58621656532924,
#    'PCN2C': 90.56233141817307,
#    'WBI': 1.7022810832574911e-06,
#    'WFMP': 2050.707884203922,
#    'ZPCN25_D': -0.01720836728248147,
#    'ZT49_D': 7.381356491232483,
#    'ZTLA_D': -0.003952590561111031,
#    'ZWF36_D': 32.12870353659652,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '0a84df34b8e0782c223c3bef55cb85eef3f554068d2d358cd17a7fc1716cbfe0',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-05-19 15:28:56',
#   'metrics': {'BRAT': 0.999999827633167,
#    'DEGT': 21.540019888653795,
#    'EGTC': 803.9971439417706,
#    'GPCN25': 0.3769465851269574,
#    'GWFM': 2.0109880206815682,
#    'PCN12': 93.87223349571701,
#    'PCN12I': 93.87212229288787,
#    'PCN1K': 99.60150443178964,
#    'PCN2C': 90.3800081610147,
#    'WBI': -1.7236870499068996e-07,
#    'WFMP': 1837.269652739013,
#    'ZPCN25_D': -0.015951724870833028,
#    'ZT49_D': 1.5326095189946258,
#    'ZTLA_D': -0.06205487432626748,
#    'ZWF36_D': -21.09476438503232,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'bf23db5ac85aa359c82cb8a18b0d0ce406fc40272a9b009ee01d62a88d4cfc61',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-04-27 20:52:30',
#   'metrics': {'BRAT': 1.0000029133982449,
#    'DEGT': 5.550612811802013,
#    'EGTC': 715.1489838197349,
#    'GPCN25': 0.5765891250528266,
#    'GWFM': 4.275459604991129,
#    'PCN12': 89.03124136647075,
#    'PCN12I': 89.03126041960297,
#    'PCN1K': 97.40298707275845,
#    'PCN2C': 86.74577882231951,
#    'WBI': 2.9133998270770498e-06,
#    'WFMP': 1620.300164584918,
#    'ZPCN25_D': 0.15785164650050382,
#    'ZT49_D': -1.588278034572218,
#    'ZTLA_D': -0.005559352527866674,
#    'ZWF36_D': 13.729561504984167,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '88a5b305e53116af2f6cfca0631bf93068d643e105cd4789b0f4cc061b25403c',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-07-06 16:18:37',
#   'metrics': {'BRAT': 0.9999994276411674,
#    'DEGT': 11.721750737000098,
#    'EGTC': 725.9368996797574,
#    'GPCN25': -0.2704549610830407,
#    'GWFM': 0.8326069260875899,
#    'PCN12': 89.03425672880667,
#    'PCN12I': 89.05291220592743,
#    'PCN1K': 95.88296728451589,
#    'PCN2C': 87.78933094613447,
#    'WBI': -5.723614786047604e-07,
#    'WFMP': 1671.63903466396,
#    'ZPCN25_D': -0.030714563819417475,
#    'ZT49_D': -1.1231156678248366,
#    'ZTLA_D': -0.020467113996557183,
#    'ZWF36_D': -32.87172060532065,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '5c888c9071d8873444bf7b6c46f7a860929703f66a89ceee7402653e6e96c500',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-01-22 13:40:45',
#   'metrics': {'BRAT': 1.000002461194953,
#    'DEGT': 59.62766834813274,
#    'EGTC': 629.4541683638096,
#    'GPCN25': 0.12920133749367546,
#    'GWFM': 4.050061770947503,
#    'PCN12': 83.96677738220163,
#    'PCN12I': 83.8572499997509,
#    'PCN1K': 93.77411154053648,
#    'PCN2C': 83.50929296226481,
#    'WBI': 2.4611993641654104e-06,
#    'WFMP': 1422.408500930607,
#    'ZPCN25_D': 0.15956932308934121,
#    'ZT49_D': 12.83338057232265,
#    'ZTLA_D': 0.005732280844802972,
#    'ZWF36_D': 24.050476603514877,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '6dc714d821a73d97c06143281b622c4e45c791985425c83cf95d770d99a8feef',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-03-06 21:07:13',
#   'metrics': {'BRAT': 0.9999996846914283,
#    'DEGT': 16.753047941994566,
#    'EGTC': 719.1760088774345,
#    'GPCN25': 0.19440266054530594,
#    'GWFM': 4.501274105789406,
#    'PCN12': 89.1549817720566,
#    'PCN12I': 89.15510613542973,
#    'PCN1K': 97.31296248079306,
#    'PCN2C': 86.96951453972477,
#    'WBI': -3.153080596228139e-07,
#    'WFMP': 1644.3205741304716,
#    'ZPCN25_D': 0.02354818340366717,
#    'ZT49_D': -2.5550159452696355,
#    'ZTLA_D': 0.02567824809498075,
#    'ZWF36_D': 6.944783978112927,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '17347326abdfbcd8acc523a9069dba5f770f1f65ca9b2138d4dc8d0bbccd3b76',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-06-27 08:21:03',
#   'metrics': {'BRAT': 0.9999962196484299,
#    'DEGT': -12.21166696853756,
#    'EGTC': 733.7925995676266,
#    'GPCN25': -0.08891919332263654,
#    'GWFM': -0.09002662026346542,
#    'PCN12': 89.4130586801532,
#    'PCN12I': 89.43516157627424,
#    'PCN1K': 95.2823023326655,
#    'PCN2C': 88.47439662008868,
#    'WBI': -3.780350148570831e-06,
#    'WFMP': 1864.9111103901591,
#    'ZPCN25_D': -0.02452972169342791,
#    'ZT49_D': -6.1861329040281765,
#    'ZTLA_D': 0.011515622715675876,
#    'ZWF36_D': -7.399301051716026,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '0a88b8ae00eb0b817075fb953711648d5d3dd8687e57946ccff881382b6606ae',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-05-17 18:03:31',
#   'metrics': {'BRAT': 0.9999998745388383,
#    'DEGT': 1.6568107707629167,
#    'EGTC': 725.1527841994598,
#    'GPCN25': 0.023887246812320406,
#    'GWFM': 1.9988230036228536,
#    'PCN12': 89.75909880218937,
#    'PCN12I': 89.76424654724309,
#    'PCN1K': 98.03044793152695,
#    'PCN2C': 87.11585516211169,
#    'WBI': -1.2546309260952349e-07,
#    'WFMP': 1665.6047562269428,
#    'ZPCN25_D': 0.061671610319303974,
#    'ZT49_D': -3.093632261364446,
#    'ZTLA_D': 0.009923970902121944,
#    'ZWF36_D': -4.0216620390169435,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'c832c947cd95db187c9409df30eedfe7af3e91136e3012f1f0305aa3b51784f3',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-03-30 09:53:27',
#   'metrics': {'BRAT': 1.0000019623394039,
#    'DEGT': 15.031738369198115,
#    'EGTC': 697.7642041116093,
#    'GPCN25': 0.011203724663535114,
#    'GWFM': 2.7884370169477024,
#    'PCN12': 88.47943457107645,
#    'PCN12I': 88.46742415592522,
#    'PCN1K': 97.95851836142302,
#    'PCN2C': 85.8301666771562,
#    'WBI': 1.962333563661385e-06,
#    'WFMP': 1681.609564721639,
#    'ZPCN25_D': -0.058121597915407656,
#    'ZT49_D': -4.075692872841789,
#    'ZTLA_D': -0.007184546206878728,
#    'ZWF36_D': -22.810605367117148,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'bf23db5ac85aa359c82cb8a18b0d0ce406fc40272a9b009ee01d62a88d4cfc61',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-02-25 02:40:37',
#   'metrics': {'BRAT': 0.9999993048475209,
#    'DEGT': 15.54012429436322,
#    'EGTC': 769.9602895129742,
#    'GPCN25': 0.9450416087884033,
#    'GWFM': 4.603853786653527,
#    'PCN12': 92.50426952432034,
#    'PCN12I': 92.49870131159408,
#    'PCN1K': 100.12504100460686,
#    'PCN2C': 88.78918815772339,
#    'WBI': -6.951544909879204e-07,
#    'WFMP': 1839.4363486319319,
#    'ZPCN25_D': 0.24063164574504203,
#    'ZT49_D': 0.3672645981770836,
#    'ZTLA_D': -0.005282040264080713,
#    'ZWF36_D': 4.626090596043742,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'bf23db5ac85aa359c82cb8a18b0d0ce406fc40272a9b009ee01d62a88d4cfc61',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-06-17 05:07:52',
#   'metrics': {'BRAT': 0.9999979603355476,
#    'DEGT': 8.43968581029175,
#    'EGTC': 767.142995790164,
#    'GPCN25': 0.5393393849445984,
#    'GWFM': 4.465860587685485,
#    'PCN12': 91.28484645803688,
#    'PCN12I': 91.30918732532025,
#    'PCN1K': 97.2920810667367,
#    'PCN2C': 89.3389783766028,
#    'WBI': -2.039666872624517e-06,
#    'WFMP': 1692.584967864197,
#    'ZPCN25_D': 0.21750334106422714,
#    'ZT49_D': -4.786132251791341,
#    'ZTLA_D': 0.0030092581106069814,
#    'ZWF36_D': 1.9429617152988476,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '8731cb5c4b82a20e9d10305dd82da733bde060eecc0c77b2ba24a4abf2781c8c',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-06-06 05:16:17',
#   'metrics': {'BRAT': 1.0000000103815667,
#    'DEGT': 21.172825090097955,
#    'EGTC': 824.1389214674738,
#    'GPCN25': 0.5435572756882026,
#    'GWFM': 2.9529217875935108,
#    'PCN12': 95.33095092733788,
#    'PCN12I': 95.34506595207736,
#    'PCN1K': 101.14238602373709,
#    'PCN2C': 90.98710716480294,
#    'WBI': 1.037886012029976e-08,
#    'WFMP': 1960.4841250350744,
#    'ZPCN25_D': 0.31921691457611984,
#    'ZT49_D': 3.670625575990473,
#    'ZTLA_D': 0.11924612237380876,
#    'ZWF36_D': -3.7996727923856763,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'd30992e9569a65764ca6f0396d90e2e4ae497927e2aae75920d6140a0d266d63',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-05-02 14:14:47',
#   'metrics': {'BRAT': 1.0000006372859516,
#    'DEGT': 18.30584288200501,
#    'EGTC': 687.5619495059649,
#    'GPCN25': 0.050596758377669526,
#    'GWFM': 1.6286085460802349,
#    'PCN12': 87.20085456745055,
#    'PCN12I': 87.1978691501246,
#    'PCN1K': 95.55486908662635,
#    'PCN2C': 85.93258924955946,
#    'WBI': 6.372850341667888e-07,
#    'WFMP': 1604.6937513390371,
#    'ZPCN25_D': -0.007443657812809795,
#    'ZT49_D': 4.974664899764042,
#    'ZTLA_D': 0.015525353684756764,
#    'ZWF36_D': 1.6198905436285005,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '88a5b305e53116af2f6cfca0631bf93068d643e105cd4789b0f4cc061b25403c',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-07-21 17:22:45',
#   'metrics': {'BRAT': 1.000002077415628,
#    'DEGT': -0.6018838232868067,
#    'EGTC': 742.3279278668364,
#    'GPCN25': 0.0006890574323342447,
#    'GWFM': 2.1063065203661107,
#    'PCN12': 90.29000109803293,
#    'PCN12I': 90.27662953112898,
#    'PCN1K': 97.59404467187547,
#    'PCN2C': 88.10002532332774,
#    'WBI': 2.077411269446952e-06,
#    'WFMP': 1674.7907263493078,
#    'ZPCN25_D': -0.01837049314348373,
#    'ZT49_D': -11.3244387817887,
#    'ZTLA_D': -0.01790667423930196,
#    'ZWF36_D': -28.137891401584096,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '17347326abdfbcd8acc523a9069dba5f770f1f65ca9b2138d4dc8d0bbccd3b76',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-04-14 04:20:56',
#   'metrics': {'BRAT': 0.9999986660010288,
#    'DEGT': -19.166277408544566,
#    'EGTC': 646.2201764251329,
#    'GPCN25': 0.27663073611841116,
#    'GWFM': 1.016100089961954,
#    'PCN12': 83.62793522694136,
#    'PCN12I': 83.6299164620157,
#    'PCN1K': 90.63182007152363,
#    'PCN2C': 84.90824760987283,
#    'WBI': -1.3340002969295522e-06,
#    'WFMP': 1555.1026724375752,
#    'ZPCN25_D': -0.012839238358352562,
#    'ZT49_D': -7.766587860115197,
#    'ZTLA_D': 0.008108273915277357,
#    'ZWF36_D': -13.425074837912023,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '2813cc69b6a3813712a16a86bea9f40e037279cb36ef23209e04d5bc89f810bf',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-06-12 15:35:00',
#   'metrics': {'BRAT': 1.0000001963166298,
#    'DEGT': 20.020921044688382,
#    'EGTC': 741.6492313344708,
#    'GPCN25': 0.22082644779321114,
#    'GWFM': 11.030881680869953,
#    'PCN12': 90.54412740227923,
#    'PCN12I': 90.5505079024932,
#    'PCN1K': 98.06894018686661,
#    'PCN2C': 87.88412610992947,
#    'WBI': 1.9631853151892004e-07,
#    'WFMP': 1699.195999421348,
#    'ZPCN25_D': -0.09865857136443583,
#    'ZT49_D': -2.9438011206656167,
#    'ZTLA_D': -0.008449160838263125,
#    'ZWF36_D': 56.33920695473328,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'b0e42606985470f2e2d77f1ad14bdd391637cc1f5c220b6d8510e285f55a1c48',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-04-22 08:29:50',
#   'metrics': {'BRAT': 0.9999991136937573,
#    'DEGT': 11.361918471764293,
#    'EGTC': 689.2507982643081,
#    'GPCN25': 0.07725382640659983,
#    'GWFM': 2.15914487410711,
#    'PCN12': 86.92174587790552,
#    'PCN12I': 86.89026734127398,
#    'PCN1K': 94.82993189272612,
#    'PCN2C': 86.10876610754207,
#    'WBI': -8.863003582481113e-07,
#    'WFMP': 1458.59578454676,
#    'ZPCN25_D': 0.009143920106085585,
#    'ZT49_D': 2.9253157696492793,
#    'ZTLA_D': 0.007112823092406081,
#    'ZWF36_D': 0.22132227440765911,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'bf23db5ac85aa359c82cb8a18b0d0ce406fc40272a9b009ee01d62a88d4cfc61',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-03-28 00:32:05',
#   'metrics': {'BRAT': 1.000001303370781,
#    'DEGT': 8.647777280086135,
#    'EGTC': 674.9796316533443,
#    'GPCN25': 0.36979371894259033,
#    'GWFM': 3.0962671706634106,
#    'PCN12': 86.79317250088978,
#    'PCN12I': 86.8067286743463,
#    'PCN1K': 96.40641663654061,
#    'PCN2C': 85.18477119648811,
#    'WBI': 1.3033678920781541e-06,
#    'WFMP': 1599.4955991469042,
#    'ZPCN25_D': 0.10989705930237559,
#    'ZT49_D': -1.1719846676644203,
#    'ZTLA_D': -0.010823538017847826,
#    'ZWF36_D': -2.3349728250288306,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'ed163ff56745c53c98f72a1f2d2b989f7472e9231378c7806d55744cb383dfa0',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-03-24 17:59:22',
#   'metrics': {'BRAT': 1.0000024730819528,
#    'DEGT': 5.802461335258178,
#    'EGTC': 553.691543870789,
#    'GPCN25': -0.28371488817123824,
#    'GWFM': 0.6826972848243202,
#    'PCN12': 76.18348343077406,
#    'PCN12I': 76.12553110419854,
#    'PCN1K': 84.1089795428776,
#    'PCN2C': 81.70058920265858,
#    'WBI': 2.4730804572270504e-06,
#    'WFMP': 1546.137529099601,
#    'ZPCN25_D': -0.25297357779243895,
#    'ZT49_D': -4.674083509003097,
#    'ZTLA_D': -0.010795889085761486,
#    'ZWF36_D': -29.512848955608572,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '60958ab5f23535a9df5c86ad4a4425e26e7bf00387221e8d826fb598f801f599',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-05-28 07:00:49',
#   'metrics': {'BRAT': 0.9999960207540887,
#    'DEGT': 25.43773355847304,
#    'EGTC': 687.5664063248444,
#    'GPCN25': 0.045762088360040615,
#    'GWFM': 4.385723255582234,
#    'PCN12': 86.80825817546159,
#    'PCN12I': 86.82126256780961,
#    'PCN1K': 93.42039710948907,
#    'PCN2C': 86.62085393597592,
#    'WBI': -3.979245195389475e-06,
#    'WFMP': 1773.5686657778676,
#    'ZPCN25_D': -0.010951113911380062,
#    'ZT49_D': 7.590763774169229,
#    'ZTLA_D': -0.004335032333768318,
#    'ZWF36_D': 30.66933507708748,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'a5309e8aa80e39434a3581d5831133fd490ac7dac8ce95ffead76b0b4e0205a5',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-05-19 02:25:20',
#   'metrics': {'BRAT': 1.0000009141759953,
#    'DEGT': 8.024290724923937,
#    'EGTC': 747.1318233078904,
#    'GPCN25': 0.19852873305631508,
#    'GWFM': 2.588380650436641,
#    'PCN12': 90.55970807166659,
#    'PCN12I': 90.56383188924528,
#    'PCN1K': 97.12618318831703,
#    'PCN2C': 88.6023056563216,
#    'WBI': 9.141774845577294e-07,
#    'WFMP': 1865.17918753999,
#    'ZPCN25_D': -0.05026356163260539,
#    'ZT49_D': -1.4473259495351356,
#    'ZTLA_D': 0.013284874226463968,
#    'ZWF36_D': -8.130949315623551,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'ed163ff56745c53c98f72a1f2d2b989f7472e9231378c7806d55744cb383dfa0',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-03-31 08:43:42',
#   'metrics': {'BRAT': 0.9999999616655438,
#    'DEGT': 35.24391815665872,
#    'EGTC': 741.1686298014113,
#    'GPCN25': -0.16126699127077798,
#    'GWFM': 2.36423987157058,
#    'PCN12': 91.7755825301453,
#    'PCN12I': 91.76876143483979,
#    'PCN1K': 101.58441363079272,
#    'PCN2C': 86.69843803255242,
#    'WBI': -3.833956490478796e-08,
#    'WFMP': 1572.4041455476083,
#    'ZPCN25_D': -0.19456856910037065,
#    'ZT49_D': 11.821769742656596,
#    'ZTLA_D': -0.025772567470714845,
#    'ZWF36_D': -14.193054052290057,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '74e006acacdc073defc46eb27660e2dfb7398acbb362399974dc5f8d9e508d94',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-04-20 22:34:05',
#   'metrics': {'BRAT': 0.9999998745707084,
#    'DEGT': 27.56057384316022,
#    'EGTC': 755.1596969525652,
#    'GPCN25': 0.24127392573931297,
#    'GWFM': 4.397468263748155,
#    'PCN12': 91.04121967334184,
#    'PCN12I': 91.08114330883755,
#    'PCN1K': 98.00058464239252,
#    'PCN2C': 88.5125221841444,
#    'WBI': -1.254290777578243e-07,
#    'WFMP': 1700.973076721133,
#    'ZPCN25_D': -0.08721381502647525,
#    'ZT49_D': 0.04859787151948031,
#    'ZTLA_D': -0.013961977208231299,
#    'ZWF36_D': 9.287282241658458,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'bf23db5ac85aa359c82cb8a18b0d0ce406fc40272a9b009ee01d62a88d4cfc61',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-07-03 23:05:24',
#   'metrics': {'BRAT': 0.9999995289047854,
#    'DEGT': 5.395752740070392,
#    'EGTC': 759.1775139258567,
#    'GPCN25': 1.0858553041607073,
#    'GWFM': 5.034927025353971,
#    'PCN12': 91.56930654752996,
#    'PCN12I': 91.58279300985627,
#    'PCN1K': 98.86157090211938,
#    'PCN2C': 88.58083071366954,
#    'WBI': -4.7109932029693047e-07,
#    'WFMP': 1783.0074582091484,
#    'ZPCN25_D': 0.24752050177235096,
#    'ZT49_D': -6.332367517640414,
#    'ZTLA_D': -0.016941690497390437,
#    'ZWF36_D': -0.1544695805484139,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '74e006acacdc073defc46eb27660e2dfb7398acbb362399974dc5f8d9e508d94',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-07-14 00:22:16',
#   'metrics': {'BRAT': 0.9999982972439699,
#    'DEGT': 15.58043057306786,
#    'EGTC': 735.6705107062189,
#    'GPCN25': 0.1788600446427934,
#    'GWFM': 2.791454892613289,
#    'PCN12': 89.85566362157049,
#    'PCN12I': 89.83775561917629,
#    'PCN1K': 96.24018329024497,
#    'PCN2C': 88.20561518573834,
#    'WBI': -1.7027558399619266e-06,
#    'WFMP': 1899.8789578829428,
#    'ZPCN25_D': -0.0013288293753115177,
#    'ZT49_D': 1.470068174309776,
#    'ZTLA_D': -0.011161985597402616,
#    'ZWF36_D': 17.972836863240406,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '6dc714d821a73d97c06143281b622c4e45c791985425c83cf95d770d99a8feef',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-05-22 06:33:03',
#   'metrics': {'BRAT': 1.000005062621246,
#    'DEGT': 24.219628973056054,
#    'EGTC': 750.6841973950337,
#    'GPCN25': 0.11978861182957705,
#    'GWFM': 4.9761960533153475,
#    'PCN12': 90.78669272462264,
#    'PCN12I': 90.78529895040245,
#    'PCN1K': 97.46000241168294,
#    'PCN2C': 88.53616641216762,
#    'WBI': 5.062622659242864e-06,
#    'WFMP': 1744.0359154223322,
#    'ZPCN25_D': 0.01694914345410797,
#    'ZT49_D': 1.082936492697373,
#    'ZTLA_D': 0.03200641253647213,
#    'ZWF36_D': -5.396115692698683,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '1627d385f689d2145daa7c859b7cb6095e7dac0420a40c4b3094e1b5b9cd3f19',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-05-20 00:49:20',
#   'metrics': {'BRAT': 1.00000026611738,
#    'DEGT': 9.437245830188484,
#    'EGTC': 719.7914273363734,
#    'GPCN25': -0.009224477680941062,
#    'GWFM': 0.10070457397003674,
#    'PCN12': 88.59910845156205,
#    'PCN12I': 88.58140840888686,
#    'PCN1K': 94.78310456570661,
#    'PCN2C': 87.8291748694945,
#    'WBI': 2.661196359231982e-07,
#    'WFMP': 1717.2710639174356,
#    'ZPCN25_D': 0.011040512925409498,
#    'ZT49_D': -1.2413493997534468,
#    'ZTLA_D': 0.0012804218312763376,
#    'ZWF36_D': -1.9607138643080906,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '17347326abdfbcd8acc523a9069dba5f770f1f65ca9b2138d4dc8d0bbccd3b76',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-06-01 15:09:53',
#   'metrics': {'BRAT': 1.0000006141587938,
#    'DEGT': -8.605740163390617,
#    'EGTC': 721.1190767452885,
#    'GPCN25': 0.3119238948164099,
#    'GWFM': 1.7439842959626457,
#    'PCN12': 89.56393954552806,
#    'PCN12I': 89.54985322496533,
#    'PCN1K': 98.03705933132669,
#    'PCN2C': 86.84484760621073,
#    'WBI': 6.141622898771931e-07,
#    'WFMP': 1661.9779481458818,
#    'ZPCN25_D': -0.028624604210206416,
#    'ZT49_D': -7.60801408271129,
#    'ZTLA_D': 0.0013959095069282698,
#    'ZWF36_D': -9.512870418935766,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '83dd5ba4ee2f515b83c6f09ffd7268f0a389b6303f0bf3a721afe7e634f87dd4',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-02-19 00:47:22',
#   'metrics': {'BRAT': 0.9999997228232438,
#    'DEGT': 37.33221577200089,
#    'EGTC': 735.877208865596,
#    'GPCN25': 0.44192931028360855,
#    'GWFM': 8.831066148778675,
#    'PCN12': 90.55387942147252,
#    'PCN12I': 90.546136834666,
#    'PCN1K': 98.80122403728453,
#    'PCN2C': 87.52977807521923,
#    'WBI': -2.77177469053258e-07,
#    'WFMP': 1774.1629936931388,
#    'ZPCN25_D': -0.07958317195196563,
#    'ZT49_D': 6.893540592975786,
#    'ZTLA_D': -0.013589166183403193,
#    'ZWF36_D': 42.38289777268049,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'b0e42606985470f2e2d77f1ad14bdd391637cc1f5c220b6d8510e285f55a1c48',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-05-05 23:46:25',
#   'metrics': {'BRAT': 1.0000025788278124,
#    'DEGT': -1.1058388647409068,
#    'EGTC': 683.4420862136681,
#    'GPCN25': 0.10982811845339271,
#    'GWFM': 0.9036282370489328,
#    'PCN12': 86.8405557328199,
#    'PCN12I': 86.81189576843572,
#    'PCN1K': 94.34989178149988,
#    'PCN2C': 86.24924076487295,
#    'WBI': 2.5788279399887454e-06,
#    'WFMP': 1725.3919125455088,
#    'ZPCN25_D': 0.028959843900712087,
#    'ZT49_D': 2.6667474971072553,
#    'ZTLA_D': 0.004401941014175891,
#    'ZWF36_D': 3.438741901118372,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '9a124d266cba9143ef7685c7bc99c07b48aaa8f1822f02d7da1ec384fd14cc2e',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-04-22 15:07:19',
#   'metrics': {'BRAT': 1.0000031613193137,
#    'DEGT': 22.221513906985706,
#    'EGTC': 726.3012492784685,
#    'GPCN25': 0.3992003303727022,
#    'GWFM': 3.605848645832365,
#    'PCN12': 89.58106894188155,
#    'PCN12I': 89.56300396316863,
#    'PCN1K': 97.62702072602374,
#    'PCN2C': 87.16584936663088,
#    'WBI': 3.161321331484647e-06,
#    'WFMP': 1619.347639736528,
#    'ZPCN25_D': 0.10056945865284456,
#    'ZT49_D': 5.371317032655701,
#    'ZTLA_D': 0.00021022228212486452,
#    'ZWF36_D': -28.71343810824234,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '5c888c9071d8873444bf7b6c46f7a860929703f66a89ceee7402653e6e96c500',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-07-12 07:47:25',
#   'metrics': {'BRAT': 0.9999980346838601,
#    'DEGT': 2.8966778464852254,
#    'EGTC': 725.1631879638912,
#    'GPCN25': 0.15203480394853902,
#    'GWFM': 1.0429558208621474,
#    'PCN12': 88.86068430585865,
#    'PCN12I': 88.86681891544882,
#    'PCN1K': 95.03088956185314,
#    'PCN2C': 88.06150520737766,
#    'WBI': -1.965315723623934e-06,
#    'WFMP': 1787.9160197178019,
#    'ZPCN25_D': 0.23734165081491426,
#    'ZT49_D': -2.9912657844188133,
#    'ZTLA_D': 0.018480330374528193,
#    'ZWF36_D': 15.564229099440196,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '6dc714d821a73d97c06143281b622c4e45c791985425c83cf95d770d99a8feef',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-07-13 02:50:18',
#   'metrics': {'BRAT': 1.000004064590952,
#    'DEGT': 10.464450253935652,
#    'EGTC': 835.2231123592949,
#    'GPCN25': 0.2541158676531019,
#    'GWFM': 5.4855431345566785,
#    'PCN12': 97.76261744142384,
#    'PCN12I': 97.7426823029201,
#    'PCN1K': 105.35088711013927,
#    'PCN2C': 90.49491388550558,
#    'WBI': 4.06456817934886e-06,
#    'WFMP': 1944.1652822187837,
#    'ZPCN25_D': 0.14253972900925976,
#    'ZT49_D': 1.64921757182059,
#    'ZTLA_D': 0.1789711458314365,
#    'ZWF36_D': 8.68652775255847,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '0a84df34b8e0782c223c3bef55cb85eef3f554068d2d358cd17a7fc1716cbfe0',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-03-13 16:12:27',
#   'metrics': {'BRAT': 1.000003918988904,
#    'DEGT': 10.828746207441643,
#    'EGTC': 625.3621833169185,
#    'GPCN25': 0.2395347953027163,
#    'GWFM': 0.8210941216148475,
#    'PCN12': 83.24262495034662,
# ...
#    'ZPCN25_D': 0.02250161308397764,
#    'ZT49_D': -8.063604871603333,
#    'ZTLA_D': 0.005631695127008847,
#    'ZWF36_D': -8.316397624164344,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '60958ab5f23535a9df5c86ad4a4425e26e7bf00387221e8d826fb598f801f599',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-07-10 20:03:40',
#   'metrics': {'BRAT': 1.0000008941186669,
#    'DEGT': 16.10125500648291,
#    'EGTC': 796.9500868859573,
#    'GPCN25': 0.10348774525829571,
#    'GWFM': 5.807887461666022,
#    'PCN12': 94.24799818034083,
#    'PCN12I': 94.26497989512994,
#    'PCN1K': 101.26927372905759,
#    'PCN2C': 89.83536291375545,
#    'WBI': 8.941188990013033e-07,
#    'WFMP': 2017.7839046834706,
#    'ZPCN25_D': -0.11134477093598606,
#    'ZT49_D': 1.1362853716976715,
#    'ZTLA_D': -0.002724133526914934,
#    'ZWF36_D': 28.491900222714843,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'ed163ff56745c53c98f72a1f2d2b989f7472e9231378c7806d55744cb383dfa0',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-01-30 07:30:09',
#   'metrics': {'BRAT': 1.000003605205304,
#    'DEGT': 30.252175738478762,
#    'EGTC': 617.6080834277219,
#    'GPCN25': -0.246622739846324,
#    'GWFM': 0.563766321002964,
#    'PCN12': 82.77834271103565,
#    'PCN12I': 82.71537874888057,
#    'PCN1K': 92.24852075205638,
#    'PCN2C': 83.31150114480091,
#    'WBI': 3.6051967451811856e-06,
#    'WFMP': 1534.6742419434468,
#    'ZPCN25_D': -0.1705935851981016,
#    'ZT49_D': -0.650446403322143,
#    'ZTLA_D': -0.00850473193393175,
#    'ZWF36_D': -12.428584711409746,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'b0e42606985470f2e2d77f1ad14bdd391637cc1f5c220b6d8510e285f55a1c48',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-02-26 19:12:29',
#   'metrics': {'BRAT': 1.000002464715741,
#    'DEGT': 3.3194289564066057,
#    'EGTC': 685.8250519382482,
#    'GPCN25': 0.12604315245849873,
#    'GWFM': 0.6138352200577342,
#    'PCN12': 87.01508289897642,
#    'PCN12I': 87.0547444661713,
#    'PCN1K': 95.11459632528026,
#    'PCN2C': 86.12956713264255,
#    'WBI': 2.464715432163797e-06,
#    'WFMP': 1733.2569754342437,
#    'ZPCN25_D': 0.033086801074873474,
#    'ZT49_D': 4.9724828719796115,
#    'ZTLA_D': 0.009530856147011903,
#    'ZWF36_D': 4.830297744287581,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '8bfd649e45c2b6d948b50e9ece01441a28f8cbe0f68849254b0019b1bfa23c03',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-02-26 04:32:25',
#   'metrics': {'BRAT': 0.999999055911109,
#    'DEGT': 18.35456790793869,
#    'EGTC': 693.7792699169304,
#    'GPCN25': 0.2947926463053753,
#    'GWFM': 1.9353151938345188,
#    'PCN12': 87.17198815868713,
#    'PCN12I': 87.18193153814983,
#    'PCN1K': 94.49589733454498,
#    'PCN2C': 86.47076473103442,
#    'WBI': -9.440886432196191e-07,
#    'WFMP': 1536.7924805080495,
#    'ZPCN25_D': 0.10546082582516003,
#    'ZT49_D': -0.38884477666434386,
#    'ZTLA_D': -0.009077091256495903,
#    'ZWF36_D': -3.9611846663552424,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '83dd5ba4ee2f515b83c6f09ffd7268f0a389b6303f0bf3a721afe7e634f87dd4',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-06-19 20:32:39',
#   'metrics': {'BRAT': 0.9999984148447969,
#    'DEGT': 9.935748027150499,
#    'EGTC': 766.1345474768461,
#    'GPCN25': -0.027080341851882517,
#    'GWFM': 6.955289034726237,
#    'PCN12': 91.37422496253015,
#    'PCN12I': 91.40449745568264,
#    'PCN1K': 97.2854018340921,
#    'PCN2C': 89.39082156389857,
#    'WBI': -1.5851565976386303e-06,
#    'WFMP': 1776.601895313001,
#    'ZPCN25_D': -0.1286145355732753,
#    'ZT49_D': -5.085116051019752,
#    'ZTLA_D': -0.013106544777432842,
#    'ZWF36_D': 33.87027726847556,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '1627d385f689d2145daa7c859b7cb6095e7dac0420a40c4b3094e1b5b9cd3f19',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-05-19 07:45:24',
#   'metrics': {'BRAT': 0.9999985170758056,
#    'DEGT': 12.012209824847591,
#    'EGTC': 774.3963007293939,
#    'GPCN25': 0.20538375937298023,
#    'GWFM': 1.9780789708663429,
#    'PCN12': 92.07581619288625,
#    'PCN12I': 92.0714201523249,
#    'PCN1K': 98.10031249122008,
#    'PCN2C': 89.55785462373004,
#    'WBI': -1.4829240486576023e-06,
#    'WFMP': 1793.7399361432463,
#    'ZPCN25_D': -0.014872556374044027,
#    'ZT49_D': -3.0797653563518455,
#    'ZTLA_D': -0.000737783320312423,
#    'ZWF36_D': -8.070513349334735,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'd30992e9569a65764ca6f0396d90e2e4ae497927e2aae75920d6140a0d266d63',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-01-26 20:44:06',
#   'metrics': {'BRAT': 0.9999980722548091,
#    'DEGT': 18.789130554262933,
#    'EGTC': 648.2058885664896,
#    'GPCN25': 0.14700480846223107,
#    'GWFM': 2.258084070429306,
#    'PCN12': 85.3803178022673,
#    'PCN12I': 85.35866059777335,
#    'PCN1K': 95.53497732129577,
#    'PCN2C': 84.05060059500586,
#    'WBI': -1.927746345072208e-06,
#    'WFMP': 1696.8019961394382,
#    'ZPCN25_D': 0.057514791830957646,
#    'ZT49_D': 3.3480778486794014,
#    'ZTLA_D': 0.005120986930003158,
#    'ZWF36_D': 12.401737635351294,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '6dc714d821a73d97c06143281b622c4e45c791985425c83cf95d770d99a8feef',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-06-25 22:25:52',
#   'metrics': {'BRAT': 1.0000008684133797,
#    'DEGT': 28.699764955110155,
#    'EGTC': 759.8241606036459,
#    'GPCN25': 0.268925614219114,
#    'GWFM': 5.824939536761001,
#    'PCN12': 91.5385160551352,
#    'PCN12I': 91.53392001011973,
#    'PCN1K': 98.70191323677193,
#    'PCN2C': 88.56593286904142,
#    'WBI': 8.684129714445904e-07,
#    'WFMP': 1754.5491947195792,
#    'ZPCN25_D': -0.017197376658480413,
#    'ZT49_D': 3.9138336800886417,
#    'ZTLA_D': 0.027175934441707118,
#    'ZWF36_D': -3.0888078933316634,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '64d46b313edfca25be20f302932207f4d667f8e1bcae043e90c7de5cb9978e80',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-02-22 23:31:03',
#   'metrics': {'BRAT': 0.9999990286428525,
#    'DEGT': 17.731594919693702,
#    'EGTC': 633.5810346573761,
#    'GPCN25': 0.2755366469185041,
#    'GWFM': 1.8577370551555843,
#    'PCN12': 83.16270055077479,
#    'PCN12I': 83.13754626066084,
#    'PCN1K': 90.96609534662834,
#    'PCN2C': 84.42561618332472,
#    'WBI': -9.713607225072043e-07,
#    'WFMP': 1500.9616488875101,
#    'ZPCN25_D': -0.09009818449858635,
#    'ZT49_D': -0.3761047189455643,
#    'ZTLA_D': 0.004324153261293708,
#    'ZWF36_D': -15.073049027341476,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '8731cb5c4b82a20e9d10305dd82da733bde060eecc0c77b2ba24a4abf2781c8c',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-07-07 16:07:10',
#   'metrics': {'BRAT': 0.9999994506689032,
#    'DEGT': 20.241426547544577,
#    'EGTC': 750.3282172419099,
#    'GPCN25': 0.36398409154633915,
#    'GWFM': 3.6072204868389233,
#    'PCN12': 90.95453856160404,
#    'PCN12I': 90.92751442377043,
#    'PCN1K': 98.07373136629431,
#    'PCN2C': 88.27471039752892,
#    'WBI': -5.493313210659309e-07,
#    'WFMP': 1714.1315013357864,
#    'ZPCN25_D': 0.07653992673517758,
#    'ZT49_D': 2.2444401879681095,
#    'ZTLA_D': 0.03830846019838354,
#    'ZWF36_D': -13.179742231179983,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'ed163ff56745c53c98f72a1f2d2b989f7472e9231378c7806d55744cb383dfa0',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-06-06 03:10:05',
#   'metrics': {'BRAT': 1.0000010808827904,
#    'DEGT': 19.073161237483347,
#    'EGTC': 837.5444112762724,
#    'GPCN25': -0.42257569781654236,
#    'GWFM': 0.033029900090778774,
#    'PCN12': 96.6262392391486,
#    'PCN12I': 96.6171607535093,
#    'PCN1K': 102.62401653022,
#    'PCN2C': 91.36346216919564,
#    'WBI': 1.0808833856819702e-06,
#    'WFMP': 2050.567112412625,
#    'ZPCN25_D': -0.20105774957370995,
#    'ZT49_D': 3.5111057849335587,
#    'ZTLA_D': -0.018905973888120778,
#    'ZWF36_D': -13.769564947068837,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '8bfd649e45c2b6d948b50e9ece01441a28f8cbe0f68849254b0019b1bfa23c03',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-06-13 20:49:41',
#   'metrics': {'BRAT': 1.0000002629137748,
#    'DEGT': 17.819641719529514,
#    'EGTC': 725.1565623612553,
#    'GPCN25': 0.4256236332108626,
#    'GWFM': 2.835844846674594,
#    'PCN12': 89.15397741286293,
#    'PCN12I': 89.15072677002566,
#    'PCN1K': 96.20974604248266,
#    'PCN2C': 87.69769504273009,
#    'WBI': 2.6291568920849134e-07,
#    'WFMP': 1764.3246573433491,
#    'ZPCN25_D': 0.14861173323398277,
#    'ZT49_D': 3.4292236209182425,
#    'ZTLA_D': -0.010260350346761378,
#    'ZWF36_D': 11.439134867036108,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '6dc714d821a73d97c06143281b622c4e45c791985425c83cf95d770d99a8feef',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-05-24 04:16:29',
#   'metrics': {'BRAT': 0.9999989768311941,
#    'DEGT': 24.41778634288719,
#    'EGTC': 729.8771731030012,
#    'GPCN25': -0.022845657299669725,
#    'GWFM': 3.6268401470698945,
#    'PCN12': 89.15166424855614,
#    'PCN12I': 89.1524049529954,
#    'PCN1K': 95.4290181127827,
#    'PCN2C': 88.15081057349616,
#    'WBI': -1.0231684096119464e-06,
#    'WFMP': 1719.4873196655574,
#    'ZPCN25_D': 0.046951602289204156,
#    'ZT49_D': 3.837588898701927,
#    'ZTLA_D': 0.02713349526004922,
#    'ZWF36_D': 0.3061735004670148,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'e2cb4b992f88d20826261a20c72983b42d625bfa5c4dfb9db818dc3548d0df1c',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-01-29 13:40:44',
#   'metrics': {'BRAT': 0.9999971046832742,
#    'DEGT': 11.152987481369689,
#    'EGTC': 629.6903196545758,
#    'GPCN25': 0.20701041383857433,
#    'GWFM': 2.7111236034868478,
#    'PCN12': 83.65534898541063,
#    'PCN12I': 83.6670550687673,
#    'PCN1K': 93.034589933108,
#    'PCN2C': 83.63795418818897,
#    'WBI': -2.8953191886556956e-06,
#    'WFMP': 1504.993934160802,
#    'ZPCN25_D': -0.09701633706645964,
#    'ZT49_D': -1.5951146434607595,
#    'ZTLA_D': 0.00521441005341656,
#    'ZWF36_D': 3.6789789815485854,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'bf23db5ac85aa359c82cb8a18b0d0ce406fc40272a9b009ee01d62a88d4cfc61',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-05-05 15:37:21',
#   'metrics': {'BRAT': 0.999998931630977,
#    'DEGT': 9.771336305586848,
#    'EGTC': 785.1371732659923,
#    'GPCN25': 0.9226947420905427,
#    'GWFM': 5.400471925436628,
#    'PCN12': 92.54772609769688,
#    'PCN12I': 92.57134310386913,
#    'PCN1K': 98.42301993624474,
#    'PCN2C': 89.86891462571089,
#    'WBI': -1.068368609804908e-06,
#    'WFMP': 1754.9127871656517,
#    'ZPCN25_D': 0.2662861369172467,
#    'ZT49_D': -4.166584790357712,
#    'ZTLA_D': -0.013000940581854796,
#    'ZWF36_D': 9.035311041503734,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': '64d46b313edfca25be20f302932207f4d667f8e1bcae043e90c7de5cb9978e80',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-01-19 09:10:35',
#   'metrics': {'BRAT': 1.0000011051672681,
#    'DEGT': 17.809578896279717,
#    'EGTC': 669.7076259288214,
#    'GPCN25': 0.22452386782929237,
#    'GWFM': 0.7918377406724613,
#    'PCN12': 86.3039883625274,
#    'PCN12I': 86.31113536087308,
#    'PCN1K': 95.04301010966053,
#    'PCN2C': 85.36565184354032,
#    'WBI': 1.1051644834558783e-06,
#    'WFMP': 1757.26083960837,
#    'ZPCN25_D': -0.0878038352314654,
#    'ZT49_D': 0.8282556228378043,
#    'ZTLA_D': 0.0071363087300120595,
#    'ZWF36_D': -16.970809300788712,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  {'engine_id': 'b89b5e1fea12a0ab78c29ca87649bf2687f1558dd0e67c93036996e81d7438c5',
#   'flight_phase': 'CRUISE',
#   'flight_datetime': '2022-06-25 02:47:32',
#   'metrics': {'BRAT': 1.0000005329827875,
#    'DEGT': 10.259738239563244,
#    'EGTC': 759.2403039043323,
#    'GPCN25': -0.4975470887240391,
#    'GWFM': 2.2432574396120533,
#    'PCN12': 91.01075602502966,
#    'PCN12I': 90.99799172027483,
#    'PCN1K': 96.7487968193148,
#    'PCN2C': 89.27197747291434,
#    'WBI': 5.329849259534322e-07,
#    'WFMP': 1913.4500268262702,
#    'ZPCN25_D': -0.2538392329126999,
#    'ZT49_D': -2.224723923146724,
#    'ZTLA_D': -0.10807067406423543,
#    'ZWF36_D': 9.43944460207485,
#    'EGTHDM': None,
#    'EGTHDM_D': None,
#    'SLOATL': None,
#    'SLOATL_D': None,
#    'DELVSV': None,
#    'DPOIL': None,
#    'GEGTMC': None,
#    'GN2MC': None,
#    'WBE': None,
#    'ZTNAC_D': None,
#    'DELFN': None,
#    'DELN1': None,
#    'PCN1AR': None,
#    'PCN1BR': None}},
#  ...]
